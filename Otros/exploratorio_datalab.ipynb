# %% [markdown]
# # Traída de datos SQL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Rutas a los archivos CSV
archivo_product = 'CSV/amazon_product.csv'
archivo_review = 'CSV/amazon_review.csv'

# Leer los archivos CSV en DataFrames
df_productos = pd.read_csv(archivo_product) 
df_review = pd.read_csv(archivo_review)

# Mostrar los encabezados de cada DataFrame
print("Encabezados de df_productos:")
print(df_productos.columns.tolist())

print("\nEncabezados de df_review:")
print(df_review.columns.tolist())

# Contar el número de filas en cada DataFrame
print("\nNúmero de datos en df_productos:", df_productos.shape[0])
print("Número de datos en df_review:", df_review.shape[0])

# Contar los nulos en cada columna de df_productos
print("\nNúmero de nulos por columna en df_productos:")
print(df_productos.isnull().sum())

# Contar los nulos en cada columna de df_review
print("\nNúmero de nulos por columna en df_review:")
print(df_review.isnull().sum())

# Contar el número total de filas duplicadas en df_productos
print("\nNúmero total de filas duplicadas en df_productos:", df_productos.duplicated().sum())

# Contar duplicados por columna en df_productos
print("\nNúmero de duplicados por columna en df_productos:")
for col in df_productos.columns:
    print(f"{col}: {df_productos.duplicated(subset=[col]).sum()}")

# Contar el número total de filas duplicadas en df_review
print("\nNúmero total de filas duplicadas en df_review:", df_review.duplicated().sum())

# Contar duplicados por columna en df_review
print("\nNúmero de duplicados por columna en df_review:")
for col in df_review.columns:
    print(f"{col}: {df_review.duplicated(subset=[col]).sum()}")
# Out:
# Encabezados de df_productos:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'about_product']
#
# Encabezados de df_review:
# ['user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link', 'product_id', 'rating', 'rating_count']
#
# Número de datos en df_productos: 1469
# Número de datos en df_review: 1465
#
# Número de nulos por columna en df_productos:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          4
# dtype: int64
#
# Número de nulos por columna en df_review:
# user_id             0
# user_name           0
# review_id           0
# review_title        0
# review_content      0
# img_link          466
# product_link      466
# product_id          0
# rating              0
# rating_count        2
# dtype: int64
#
# ...

# %% [markdown]
# # Traída de datos limpios CSV

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import HTML

# Rutas a los archivos CSV
archivo_product = 'CSV/amazon_product_clean.csv'
archivo_review = 'CSV/amazon_review_clean.csv'

# Leer los archivos CSV en DataFrames
df_productos = pd.read_csv(archivo_product) 
df_review = pd.read_csv(archivo_review)

# Mostrar los encabezados de cada DataFrame
print("Encabezados de df_productos:")
print(df_productos.columns.tolist())

print("\nEncabezados de df_review:")
print(df_review.columns.tolist())

# Contar el número de filas en cada DataFrame
print("\nNúmero de datos en df_productos:", df_productos.shape[0])
print("Número de datos en df_review:", df_review.shape[0])

# Contar los nulos en cada columna de df_productos
print("\nNúmero de nulos por columna en df_productos:")
print(df_productos.isnull().sum())

# Contar los nulos en cada columna de df_review
print("\nNúmero de nulos por columna en df_review:")
print(df_review.isnull().sum())

# Contar el número total de filas duplicadas en df_productos
print("\nNúmero total de filas duplicadas en df_productos:", df_productos.duplicated().sum())

# Contar duplicados por columna en df_productos
print("\nNúmero de duplicados por columna en df_productos:")
for col in df_productos.columns:
    print(f"{col}: {df_productos.duplicated(subset=[col]).sum()}")

# Contar el número total de filas duplicadas en df_review
print("\nNúmero total de filas duplicadas en df_review:", df_review.duplicated().sum())

# Contar duplicados por columna en df_review
print("\nNúmero de duplicados por columna en df_review:")
for col in df_review.columns:
    print(f"{col}: {df_review.duplicated(subset=[col]).sum()}")
# Out:
# Encabezados de df_productos:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'about_product', 'appearance_rank']
#
# Encabezados de df_review:
# ['reviews_count', 'review_title', 'review_content', 'img_link', 'product_link', 'product_id', 'rating', 'rating_count']
#
# Número de datos en df_productos: 1351
# Número de datos en df_review: 1186
#
# Número de nulos por columna en df_productos:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          0
# appearance_rank        0
# dtype: int64
#
# Número de nulos por columna en df_review:
# reviews_count     0
# review_title      0
# review_content    0
# img_link          0
# product_link      0
# product_id        0
# rating            0
# rating_count      0
# dtype: int64
#
# Número total de filas duplicadas en df_productos: 0
#
# ...

# %% [markdown]
# # Traída de datos SQL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import HTML
from sqlalchemy import create_engine
from IPython.display import display

# Crear una cadena de conexión para SQLAlchemy
engine = create_engine('postgresql+psycopg2://osiris:121041@localhost:5432/datalab-osiris')

# Consulta para obtener el encabezado de la tabla amazon_review_clean
query_review_clean = "SELECT * FROM amazon_review_clean"
df_review = pd.read_sql_query(query_review_clean, engine)

# Consulta para obtener el encabezado de la tabla amazon_product_clean
query_product_clean = "SELECT * FROM amazon_product_clean"
df_product = pd.read_sql_query(query_product_clean, engine)

# Mostrar encabezados con display
print("Encabezado de amazon_review_clean:")
# Usa display() para mostrar el DataFrame
display(df_review)  

print("\nEncabezado de amazon_product_clean:")
# Usa display() para mostrar el DataFrame
display(df_product)
# Out:
# Encabezado de amazon_review_clean:
#       reviews_count                                       review_title  \
# 0                 5  Nice product i recommend to buy,Do not buy!! D...
# 1                 8  Nice,Good Quality,Good product,Product is good...
# 2                 8  Good,Value for money,Good,Under 500 tds, it ge...
# 3                 8  Perfect fit n finish. But slightly over priced...
# 4                 8  Worth of money,There is no 8 gb storage only 2...
# ...             ...                                                ...
# 1181              8  Excellent product,Good product, very accurate ...
# 1182              8  Excellent Product,Good,👍,Meets purpose,Nice ba...
# 1183              8  Excellent product,Great Quality,Good,V good pr...
# 1184              8  Excellent product. vlue for money,Decent produ...
# 1185              6  Excellent solution for Sony TVs,Worth purchase...
#
#                                          review_content  img_count  \
# ...

# %%
# Configuración del estilo del gráfico
sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  

# Creación del boxplot para 'reviews_count'
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['reviews_count'], color='#ADD8E6')
plt.title('reviews_count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_review['rating'] = df_review['rating'].astype(str)

# Reemplazar las comas por puntos y convertir a numérico
df_review['rating'] = pd.to_numeric(df_review['rating'].str.replace(',', '.', regex=False), errors='coerce')

# Ordenar el DataFrame por 'rating'
df_review = df_review.sort_values(by='rating')

# Configurar el estilo de los gráficos
sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['rating'], color='#ADD8E6')
plt.title('Distribución de Ratings')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_review['rating'] = df_review['rating'].astype(str)

# Reemplazar las comas por puntos y convertir a numérico (float)
df_review['rating'] = pd.to_numeric(df_review['rating'].str.replace(',', '.', regex=False), errors='coerce')

# Crear el histograma
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(df_review['rating'], bins=10, kde=False, color='#FFA07A')  # Color anaranjado claro

# Añadir etiquetas de datos encima de las barras
for p in hist_plot.patches:
    height = p.get_height()
    hist_plot.annotate(f'{int(height)}', 
                       (p.get_x() + p.get_width() / 2., height),
                       ha='center', va='center', 
                       xytext=(0, 5), textcoords='offset points', fontsize=12)

# Configuraciones del gráfico
plt.title('Distribución de Ratings')
plt.xlabel('Rating')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.7)  # Estilo de rejilla
plt.tight_layout()

# Mostrar el histograma
plt.show()

# %% [markdown]
# ## Valores menores a 3

# %%
count_less_than_3 = df_review[df_review['rating'] < 3].shape[0]

result_df = pd.DataFrame({
    'Valores menores a 3': [count_less_than_3]
})


print(result_df)
# Out:
#    Valores menores a 3
# 0                    7

# %%
# Convertir la columna 'rating_count' a tipo numérico (int)
df_review['rating_count'] = pd.to_numeric(df_review['rating_count'], errors='coerce')

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['rating_count'], color='#ADD8E6')
plt.title('rating_count')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Valores por encima de 200.000

# %%
count_values = df_review[df_review['rating_count'] > 200000].shape[0]

result_df = pd.DataFrame({
    'Valores ': [count_values]
})

print(result_df)
# Out:
#    Valores
# 0         7

# %%
# Eliminar el símbolo ₹ y convertir a número
df_product['discounted_price'] = df_product['discounted_price'].replace({'₹': ''}, regex=True)
df_product['discounted_price'] = pd.to_numeric(df_product['discounted_price'], errors='coerce')

# Convertir a entero, manejando NaNs
df_product['discounted_price'] = df_product['discounted_price'].fillna(0).astype(int)

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['discounted_price'], color='#ADD8E6')
plt.title('discounted_price')

plt.tight_layout()
plt.show()

# %%
count_values = df_product[df_product['discounted_price'] > 40000].shape[0]

result_df = pd.DataFrame({
    'Valores ': [count_values]
})

print(result_df)
# Out:
#    Valores
# 0        10

# %%
# Eliminar el símbolo ₹ y convertir a número
df_product['actual_price'] = df_product['actual_price'].replace({'₹': ''}, regex=True)
df_product['actual_price'] = pd.to_numeric(df_product['actual_price'], errors='coerce')


df_product['actual_price'] = df_product['actual_price'].fillna(0).astype(int)

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['actual_price'], color='#ADD8E6')
plt.title('actual_price')

plt.tight_layout()
plt.show()

# %%
count_values = df_product[df_product['actual_price'] > 80000].shape[0]

result_df = pd.DataFrame({
    'Valores ': [count_values]
})

print(result_df)
# Out:
#    Valores
# 0         2

# %%
df_product_sorted = df_product.sort_values(by='discount_percentage', ascending=False)

# Función para ajustar el formato de las celdas en HTML
def render_dataframe(df, max_rows=10):
    html = df.head(max_rows).to_html(index=False, escape=False)
    # Ajustar el estilo de las celdas para truncar texto y limitar el ancho
    html = html.replace('<td>', '<td style="max-width: 200px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap;">')
    return html

# Mostrar los primeros 10 registros con el ajuste de truncamiento
display(HTML(render_dataframe(df_product_sorted)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>product_id</th>
#       <th>product_name</th>
#       <th>general_category</th>
#       <th>specific_category</th>
#       <th>discounted_price</th>
#       <th>actual_price</th>
#       <th>discount_percentage</th>
#       <th>about_product</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="max-width: 200px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap;">B097C564GC</td>
#       <td style="max-width: 200px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap;">rts [2 Pack] Mini USB C Type C Adapter Plug, Type C Female to USB A Male Charger Charging Cable Adapter Converter compatible for iPhone, Samsung S20 ultra/S21/S10/S8/S9/MacBook Pro iPad Silver</td>
#       <td style="max-width: 200px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap;">Computers&Accessories</td>
# ...

# %%
# Convertir 'discount_percentage' a números y multiplicar por 100
df_product['discount_percentage'] = pd.to_numeric(df_product['discount_percentage'], errors='coerce')
df_product['discount_percentage'] = df_product['discount_percentage'] * 100

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['discount_percentage'], color='#ADD8E6')
plt.title('Discount Percentage')

# Configurar los ticks del eje x para que muestren valores en porcentaje
max_value = df_product['discount_percentage'].max()
plt.xticks(ticks=range(0, int(max_value) + 10, 10), labels=[f'{i}%' for i in range(0, int(max_value) + 10, 10)], rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Convertir la columna 'discount_percentage' a cadena si no es ya una
df_product['discount_percentage'] = df_product['discount_percentage'].astype(str)

# Eliminar el símbolo '%' y reemplazar comas por puntos
df_product['discount_percentage'] = pd.to_numeric(df_product['discount_percentage'].str.replace('%', '').str.replace(',', '.'), errors='coerce')

# Calcular los cuartiles
q1 = df_product['discount_percentage'].quantile(0.25)
q2 = df_product['discount_percentage'].quantile(0.50)
q3 = df_product['discount_percentage'].quantile(0.75)

# Contar los datos en cada cuartil
count_q1 = df_product[df_product['discount_percentage'] <= q1].shape[0]
count_q2 = df_product[(df_product['discount_percentage'] > q1) & (df_product['discount_percentage'] <= q2)].shape[0]
count_q3 = df_product[(df_product['discount_percentage'] > q2) & (df_product['discount_percentage'] <= q3)].shape[0]
count_q4 = df_product[df_product['discount_percentage'] > q3].shape[0]

# Crear un resumen
summary = {
    'Cuartil 1': {'Porcentaje de descuento': q1, 'Datos': count_q1},
    'Cuartil 2': {'Porcentaje de descuento': q2, 'Datos': count_q2},
    'Cuartil 3': {'Porcentaje de descuento': q3, 'Datos': count_q3},
    'Cuartil 4': {'Porcentaje de descuento': 'Más de ' + str(q3), 'Datos': count_q4}
}

# Mostrar el resumen
for cuartil, info in summary.items():
    print(f"{cuartil}: Menores a {info['Porcentaje de descuento']}%, hay {info['Datos']} datos")
# Out:
# Cuartil 1: Menores a 31.0%, hay 350 datos
# Cuartil 2: Menores a 49.0%, hay 339 datos
# Cuartil 3: Menores a 62.0%, hay 327 datos
# Cuartil 4: Menores a Más de 62.0%, hay 335 datos

# %% [markdown]
# # Exploración de categorias Dummies

# %%
# Separar las categorías en columnas dummy
df_categories = df_product['category'].str.get_dummies(sep='|')

# Concatenar las columnas dummy al DataFrame original
df_product = pd.concat([df_product, df_categories], axis=1)

# Contar las ocurrencias de cada categoría
category_counts = df_categories.sum().sort_values(ascending=False)

# Crear la columna de total_categorías
df_product['total_categorias'] = df_categories.sum(axis=1)

# Ordenar el DataFrame por el total de categorías de mayor a menor
df_product_sorted = df_product.sort_values(by='total_categorias', ascending=False)

# Seleccionar las columnas a mostrar
columns_to_display = ['product_name', 'category'] + list(df_categories.columns) + ['total_categorias']
df_result = df_product_sorted[columns_to_display]

# Mostrar el resultado
display(df_result)

# Leer el DataFrame
df_product = pd.read_csv('CSV/amazon_product_clean.csv')

# Separar las categorías en columnas dummy
df_categories = df_product['category'].str.get_dummies(sep='|')

# Concatenar las columnas dummy al DataFrame original
df_product = pd.concat([df_product, df_categories], axis=1)

# Contar las ocurrencias de cada categoría
category_counts = df_categories.sum().sort_values(ascending=False)

# Crear la columna de total_categorías
df_product['total_categorias'] = df_categories.sum(axis=1)

# Ordenar el DataFrame por el total de categorías de mayor a menor
df_product_sorted = df_product.sort_values(by='total_categorias', ascending=False)

# Seleccionar las columnas a mostrar
columns_to_display = ['product_name', 'category'] + list(df_categories.columns) + ['total_categorias']
df_result = df_product_sorted[columns_to_display]


# Imprimir el número total de categorías dummy creadas
print(f"Total de categorías dummy creadas: {len(df_categories.columns)}")

# Crear un DataFrame con las categorías y su conteo de apariciones
category_summary = pd.DataFrame({
    'Categoria': category_counts.index,
    'Conteo': category_counts.values
})

# Ajustar pandas para mostrar todas las filas sin truncar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Mostrar el DataFrame con las categorías y su conteo de apariciones
display(category_summary)
# Out:
#                                                                                                                                                                                                product_name  \
# 239                                                                                          Parker Vector Camouflage Gift Set - Roller Ball Pen & Parker Logo Keychain (Black Body, Blue Ink), 2 Piece Set
# 109                                                                                                                                                   Pilot Frixion Clicker Roller Pen (Blue), (9000019529)
# 435                           Classmate Octane Neon- 25 Blue Gel Pens | Smooth Writing Pens| Water-proof Ink For Smudge-free Writing| Preferred By Students For Exam & Class Notes| Study At Home Essential
# ...

# %%
import pandas as pd

# Asegurarse de que la columna 'rating_count' sea numérica
df_review['rating_count'] = pd.to_numeric(df_review['rating_count'], errors='coerce')

# Calcular los cuartiles, máximo, mínimo y desviación estándar
quartiles = df_review['rating_count'].quantile([0.25, 0.5, 0.75])

max_value = df_review['rating_count'].max()
min_value = df_review['rating_count'].min()
std_dev = df_review['rating_count'].std()

# Crear un display bonito de los resultados
summary = pd.DataFrame({
    'Descripción': ['Cuartil 1', 'Cuartil 2', 'Cuartil 3', 'Cuartil 4', 'Valor Máximo', 'Valor Mínimo', 'Desviación Estándar'],
    'Valor': [
        f'Menor a {quartiles[0.25]}',
        f'Menor a {quartiles[0.5]}',
        f'Menor a {quartiles[0.75]}',
        f'Mayores de {quartiles[0.75]}',
        max_value,
        min_value,
        std_dev
    ]
})

# Mostrar los resultados
summary.style.set_table_styles(
    [{'selector': 'th', 'props': [('background-color', '#f0f0f0'), ('color', 'black'), ('font-weight', 'bold')]}]
)
# Out:
# <style type="text/css">
# #T_c2330 th {
#   background-color: #f0f0f0;
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_c2330">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2330_level0_col0" class="col_heading level0 col0" >Descripción</th>
#       <th id="T_c2330_level0_col1" class="col_heading level0 col1" >Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2330_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2330_row0_col0" class="data row0 col0" >Cuartil 1</td>
#       <td id="T_c2330_row0_col1" class="data row0 col1" >Menor a 946.25</td>
#     </tr>
#     <tr>
#       <th id="T_c2330_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2330_row1_col0" class="data row1 col0" >Cuartil 2</td>
#       <td id="T_c2330_row1_col1" class="data row1 col1" >Menor a 3762.5</td>
#     </tr>
#     <tr>
# ...

# %%
category_counts = df_review['category_rating_count'].value_counts().reset_index()
category_counts.columns = ['category_rating_count', 'count']


plt.figure(figsize=(10, 6))
palette = {
    'Poco confiable': '#FF69B4',  # Rosa
    'Medio confiable': '#FFA500',  # Anaranjado
    'Moderadamente confiable': '#DDA0DD',  # Morado
    'Confiable': '#228B22'  # Verde 
}

bar_plot = sns.barplot(data=category_counts, x='category_rating_count', y='count', hue='category_rating_count', palette=palette, legend=False)


for index, row in category_counts.iterrows():
    bar_plot.text(row.name, row['count'], round(row['count'], 2), color='black', ha='center')


plt.title('Conteo de Categorías de Rating Count')
plt.xlabel('Categoría de Rating Count')
plt.ylabel('Conteo')


# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Crear una cadena de conexión para SQLAlchemy
engine = create_engine('postgresql+psycopg2://osiris:121041@localhost:5432/datalab-osiris')

# Consulta para obtener el encabezado de la tabla amazon_review_clean
query_review_clean = "SELECT * FROM review_final"
df_review_final = pd.read_sql_query(query_review_clean, engine)

# Consulta para obtener el encabezado de la tabla amazon_product_clean
query_product_clean = "SELECT * FROM product_final"
df_product_final = pd.read_sql_query(query_product_clean, engine)

# Mostrar encabezados con display
print("Encabezado de review")
# Usa display() para mostrar el DataFrame
display(df_review_final)  

print("\nEncabezado de product")
# Usa display() para mostrar el DataFrame
display(df_product_final)
# Out:
# Encabezado de review
#       reviews_count                                       review_title                                     review_content  img_count                                           img_link                                       product_link  product_id  rating category_rating  rating_count    category_rating_count                    rating_segmentation
# 0                 8  Perfect fit n finish. But slightly over priced...  Perfect fit n finish. But slightly over priced...          2  https://m.media-amazon.com/images/I/4155YhLwDi...  https://www.amazon.in/Sounce-Protective-Case-X...  B09SJ1FTYV     4.0            Alto          4740  Moderadamente confiable  Rating Alto (Moderadamente confiable)
# ...

# %%
# Mostrar encabezados de df_review_final
print("Encabezado de review")
print(df_review_final.columns.tolist())

# Mostrar encabezados de df_product_final
print("\nEncabezado de product")
print(df_product_final.columns.tolist())
# Out:
# Encabezado de review
# ['reviews_count', 'review_title', 'review_content', 'img_count', 'img_link', 'product_link', 'product_id', 'rating', 'category_rating', 'rating_count', 'category_rating_count', 'rating_segmentation']
#
# Encabezado de product
# ['product_id', 'product_name', 'general_category', 'specific_category', 'discounted_price', 'actual_price', 'discount_percentage', 'category_discount', 'about_product']

# %% [markdown]
# # Datos Amazon unificado TODOS final

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import HTML
from sqlalchemy import create_engine
from IPython.display import display
# Crear una cadena de conexión para SQLAlchemy
engine = create_engine('postgresql+psycopg2://osiris:121041@localhost:5432/datalab-osiris')

# Consulta para obtener el encabezado de la tabla amazon_review_clean
query_review_clean = "SELECT * FROM amazon_unificado"
amazon_unificado = pd.read_sql_query(query_review_clean, engine)

print(amazon_unificado.columns.tolist())

print("\nEncabezado del Unificado")
# Usa display() para mostrar el DataFrame
#display(amazon_unificado)
# Out:
# ['product_id', 'reviews_count', 'review_title', 'review_content', 'img_count', 'img_link', 'product_link', 'rating', 'category_rating', 'rating_count', 'category_rating_count', 'rating_segmentation', 'product_name', 'general_category', 'specific_category', 'discounted_price', 'actual_price', 'discount_percentage', 'category_discount', 'about_product']
#
# Encabezado del Unificado

# %%
from collections import Counter
import re
import pandas as pd

# Concatenar 'review_title' y 'review_content'
amazon_unificado['title_content'] = amazon_unificado['review_title'] + " " + amazon_unificado['review_content']

# Función para limpiar y contar palabras
def contar_palabras(texto):
    # Convertir a minúsculas
    texto = texto.lower()
    # Eliminar caracteres especiales y dividir en palabras
    palabras = re.findall(r'\b\w{4,}\b', texto)
    # Contar palabras
    return Counter(palabras)

# Aplicar la función a toda la columna 'title_content'
conteo_palabras = amazon_unificado['title_content'].apply(contar_palabras)

# Sumar todos los contadores para obtener las 25 palabras más comunes
suma_conteos = sum(conteo_palabras, Counter())
palabras_comunes = [palabra for palabra, _ in suma_conteos.most_common(25)]

# Crear columnas para cada una de las 25 palabras más comunes
for palabra in palabras_comunes:
    amazon_unificado[palabra] = amazon_unificado['title_content'].apply(lambda x: x.lower().split().count(palabra))

# Seleccionar solo las columnas de interés
amazon_resultado = amazon_unificado[['title_content'] + palabras_comunes]

# Exportar el DataFrame resultante a un archivo HTML
amazon_resultado.to_html('amazon_resultado.html', index=False)

# Convertir el conteo total a DataFrame para un mejor display
df_suma_conteos = pd.DataFrame(suma_conteos.items(), columns=['Palabra', 'Conteo']).sort_values(by='Conteo', ascending=False)

# Exportar el DataFrame de conteo total a un archivo HTML
df_suma_conteos.to_html('conteo_total.html', index=False)

print("Los archivos se han exportado como 'amazon_resultado.html' y 'conteo_total.html'.")
# Out:
# Los archivos se han exportado como 'amazon_resultado.html' y 'conteo_total.html'.

# %%
# Contar las ocurrencias de cada categoría en general_category
category_counts = amazon_unificado['general_category'].apply(lambda x: pd.Series(x.split('|'))).stack().value_counts()

# Crear una nueva columna con el total de categorías por fila
amazon_unificado['total_categorias'] = amazon_unificado['general_category'].apply(lambda x: len(x.split('|')))

# Ordenar el DataFrame por el total de categorías de mayor a menor
amazon_unificado_sorted = amazon_unificado.sort_values(by='total_categorias', ascending=False)

# Seleccionar las columnas a mostrar
columns_to_display = ['product_name', 'general_category', 'total_categorias']
df_result = amazon_unificado_sorted[columns_to_display]

# Crear un DataFrame con las categorías y su conteo de apariciones
category_summary = pd.DataFrame({
    'Categoria': category_counts.index,
    'Conteo': category_counts.values
})

# Ajustar pandas para mostrar todas las filas sin truncar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Mostrar el DataFrame con las categorías y su conteo de apariciones
display(category_summary)
# Out:
#                Categoria  Conteo
# 0           Home&Kitchen     444
# 1            Electronics     369
# 2  Computers&Accessories     319
# 3         OfficeProducts      31
# 4     MusicalInstruments       2
# 5        HomeImprovement       2
# 6          Car&Motorbike       1
# 7             Toys&Games       1
# 8    Health&PersonalCare       1

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# DataFrame para almacenar datos numéricos
amazon_numericos = pd.DataFrame()

# Recorrer cada columna y validar tipo de dato
for column in amazon_unificado.columns:
    try:
        # Verificar si la columna tiene valores numéricos
        if amazon_unificado[column].apply(lambda x: str(x).replace('.', '', 1).isdigit()).all():
            # Convertir a tipo numérico
            amazon_unificado[column] = pd.to_numeric(amazon_unificado[column], errors='coerce')
            amazon_numericos[column] = amazon_unificado[column]
        else:
            # Si es string, mantener en el DataFrame original
            amazon_unificado[column] = amazon_unificado[column].astype(str)
    except Exception as e:
        print(f"Error procesando la columna '{column}': {e}")

# Manejo de valores nulos - Llenar nulos con la mediana para evitar NaN
amazon_numericos.fillna(amazon_numericos.median(), inplace=True)

# Mensaje si el DataFrame de datos numéricos está vacío
if amazon_numericos.empty:
    print("No se encontraron columnas numéricas en el DataFrame.")

# Medidas de tendencia central y dispersión para datos numéricos, agrupadas por 'general_category'
try:
    if not amazon_numericos.empty:
        # Agregar la columna 'general_category' al DataFrame numérico
        amazon_numericos['general_category'] = amazon_unificado['general_category']
        
        # Agrupar por 'general_category' y calcular las estadísticas básicas
        tendencia_central = amazon_numericos.groupby('general_category').agg(
            Media=('discounted_price', 'mean'),
            Desviación_Estándar=('discounted_price', 'std'),
            Varianza=('discounted_price', 'var'),
            Mediana=('discounted_price', 'median'),
            Primer_Cuartil_25=('discounted_price', lambda x: np.percentile(x.dropna(), 25)),
            Tercer_Cuartil_75=('discounted_price', lambda x: np.percentile(x.dropna(), 75)),
            Mínimo=('discounted_price', 'min'),
            Máximo=('discounted_price', 'max'),
            Moda=('discounted_price', lambda x: x.mode()[0] if not x.mode().empty else np.nan)
        )
        
        # Calcular el rango intercuartil (IQR)
        tendencia_central['Rango_Intercuartil'] = tendencia_central['Tercer_Cuartil_75'] - tendencia_central['Primer_Cuartil_25']

        # Transponer la tabla para que las categorías estén en filas y las medidas en columnas
        tendencia_central = tendencia_central.T
        
        # Mostrar la tabla resultante
        display(tendencia_central)
    else:
        print("No se pueden calcular medidas de tendencia central porque no hay columnas numéricas.")
except Exception as e:
    print(f"Error calculando las medidas de tendencia central: {e}")

# Verificación de errores en columnas string
for column in amazon_unificado.columns:
    if amazon_unificado[column].dtype == 'object':
        if any(amazon_unificado[column].str.contains('[^0-9.]', regex=True)):
            print(f"Advertencia: La columna '{column}' contiene caracteres no numéricos.")
# Out:
# general_category     Car&Motorbike  Computers&Accessories   Electronics  \
# Media                       2339.0           1.040336e+03  4.164518e+03
# Desviación_Estándar            NaN           2.810898e+03  7.457953e+03
# Varianza                       NaN           7.901145e+06  5.562106e+07
# Mediana                     2339.0           4.490000e+02  9.990000e+02
# Primer_Cuartil_25           2339.0           2.490000e+02  3.490000e+02
# Tercer_Cuartil_75           2339.0           9.490000e+02  2.599000e+03
# Mínimo                      2339.0           3.900000e+01  8.900000e+01
# Máximo                      2339.0           3.724700e+04  3.799000e+04
# Moda                        2339.0           1.990000e+02  3.990000e+02
# Rango_Intercuartil             0.0           7.000000e+02  2.250000e+03
#
# general_category     Health&PersonalCare  Home&Kitchen  HomeImprovement  \
# Media                              899.0  2.246687e+03       337.000000
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot

# Asegurarse de que las columnas 'rating' y 'discount_percentage' sean numéricas
amazon_unificado['rating'] = pd.to_numeric(amazon_unificado['rating'], errors='coerce')
amazon_unificado['discount_percentage'] = pd.to_numeric(amazon_unificado['discount_percentage'], errors='coerce')

# Paso 1: Identificación del Tipo de Variables
rating_is_numeric = pd.api.types.is_numeric_dtype(amazon_unificado['rating'])
discount_is_numeric = pd.api.types.is_numeric_dtype(amazon_unificado['discount_percentage'])

if rating_is_numeric and discount_is_numeric:
    variable_type = "Ambas variables son continuas."
    print(f"Variables: 'rating' y 'discount_percentage' son continuas y numéricas.")

    # Paso 2: Evaluación de la Distribución de los Datos
    print("\nPaso 2: Evaluación de la Distribución de los Datos")

    # Test de normalidad para 'rating'
    rating_shapiro = stats.shapiro(amazon_unificado['rating'].dropna())
    print(f"Shapiro-Wilk Test para 'rating': p-valor = {rating_shapiro.pvalue:.4f}")

    # Test de normalidad para 'discount_percentage'
    discount_shapiro = stats.shapiro(amazon_unificado['discount_percentage'].dropna())
    print(f"Shapiro-Wilk Test para 'discount_percentage': p-valor = {discount_shapiro.pvalue:.4f}")

    # Visualización de la distribución
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(amazon_unificado['rating'].dropna(), kde=True, color='blue')
    plt.title('Distribución de Rating')

    plt.subplot(1, 2, 2)
    sns.histplot(amazon_unificado['discount_percentage'].dropna(), kde=True, color='green')
    plt.title('Distribución de Discount Percentage')
    plt.show()

    # Q-Q Plots para ver la normalidad
    qqplot(amazon_unificado['rating'].dropna(), line='s')
    plt.title('Q-Q Plot para Rating')
    plt.show()

    qqplot(amazon_unificado['discount_percentage'].dropna(), line='s')
    plt.title('Q-Q Plot para Discount Percentage')
    plt.show()

    # Paso 3: Selección del Test Estadístico
    print("\nPaso 3: Selección del Test Estadístico")
    if rating_shapiro.pvalue > 0.05 and discount_shapiro.pvalue > 0.05:
        # Ambas variables siguen una distribución normal
        print("Ambas variables siguen una distribución normal. Se utilizará el Test de Correlación de Pearson y el Test de Correlación de Kendall.")
        corr_test1 = "pearson"
        correlation1, p_value1 = stats.pearsonr(amazon_unificado['rating'].dropna(), amazon_unificado['discount_percentage'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating'].dropna(), amazon_unificado['discount_percentage'].dropna())
        
    else:
        # Al menos una variable no sigue una distribución normal
        print("Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.")
        corr_test1 = "spearman"
        correlation1, p_value1 = stats.spearmanr(amazon_unificado['rating'].dropna(), amazon_unificado['discount_percentage'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating'].dropna(), amazon_unificado['discount_percentage'].dropna())

    # Paso 4: Verificación de Supuestos y Resultados
    print("\nPaso 4: Verificación de Supuestos y Resultados")

    def describe_correlation(correlation):
        if correlation == 1:
            return "perfecta y positiva"
        elif correlation == -1:
            return "perfecta y negativa"
        elif 0.7 < correlation < 1:
            return "fuerte y positiva"
        elif -1 < correlation < -0.7:
            return "fuerte y negativa"
        elif 0.4 < correlation <= 0.7:
            return "moderada y positiva"
        elif -0.7 <= correlation < -0.4:
            return "moderada y negativa"
        elif 0.2 < correlation <= 0.4:
            return "débil y positiva"
        elif -0.4 <= correlation < -0.2:
            return "débil y negativa"
        else:
            return "muy débil"

    # Resultados del Test 1
    print(f"Test 1 Seleccionado: {corr_test1.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation1:.4f} ({describe_correlation(correlation1)})")
    print(f"p-valor: {p_value1:.4f}")
    if p_value1 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de {corr_test1.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de {corr_test1.capitalize()}.")

    # Resultados del Test 2
    print(f"\nTest 2 Seleccionado: {corr_test2.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation2:.4f} ({describe_correlation(correlation2)})")
    print(f"p-valor: {p_value2:.4f}")
    if p_value2 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de {corr_test2.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de {corr_test2.capitalize()}.")

else:
    print("Una o ambas variables no son numéricas. No se puede realizar la correlación.")
# Out:
# Variables: 'rating' y 'discount_percentage' son continuas y numéricas.
#
# Paso 2: Evaluación de la Distribución de los Datos
# Shapiro-Wilk Test para 'rating': p-valor = 0.0000
# Shapiro-Wilk Test para 'discount_percentage': p-valor = 0.0000
# Paso 3: Selección del Test Estadístico
# Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.
#
# Paso 4: Verificación de Supuestos y Resultados
# Test 1 Seleccionado: Spearman Correlation Test
# Coeficiente de Correlación: -0.1626 (muy débil)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de Spearman.
#
# Test 2 Seleccionado: Kendall Correlation Test
# Coeficiente de Correlación: -0.1151 (muy débil)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating' y 'discount_percentage' según el test de Kendall.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse de que no haya valores nulos
amazon_unificado_clean = amazon_unificado.dropna(subset=['rating', 'discount_percentage'])

# Crear el scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='discount_percentage', y='rating', data=amazon_unificado_clean, color='blue', alpha=0.6)

# Añadir la línea de tendencia
sns.regplot(x='discount_percentage', y='rating', data=amazon_unificado_clean, scatter=False, color='red', line_kws={"lw":2})

plt.title('Relación entre Rating y Discount Percentage')
plt.xlabel('Discount Percentage')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Obtener los datos únicos y convertirlos a un DataFrame
unique_rating_segmentation_df = pd.DataFrame(amazon_unificado['category_rating_count'].unique(), columns=['unique_rating_segmentation'])

# Mostrar el DataFrame resultante
print(unique_rating_segmentation_df)
# Out:
#   unique_rating_segmentation
# 0    Moderadamente confiable
# 1            Medio confiable
# 2             Poco confiable
# 3                  Confiable

# %%
import pandas as pd
from IPython.display import display, HTML

def display_with_scroll(df, max_height='400px', max_width='50%'):
    """
    Muestra un DataFrame en un contenedor con scroll para facilitar la visualización.
    
    Args:
    - df (pd.DataFrame): El DataFrame a mostrar.
    - max_height (str): Altura máxima del contenedor, acepta valores como '400px' o '50vh'.
    - max_width (str): Ancho máximo del contenedor, acepta valores como '50%' o '600px'.
    """
    # Convertir el DataFrame a HTML
    html = df.to_html(classes='table table-striped', index=False)
    
    # Estilo para el contenedor de scroll
    scroll_style = f"""
    <style>
        .scrollable-table {{
            max-height: {max_height};
            max-width: {max_width};
            overflow-y: auto;
            overflow-x: auto;
            display: block;
            margin: 0 auto; /* Centra el contenedor horizontalmente */
        }}
        .scrollable-table table {{
            width: 100%;
        }}
    </style>
    """
    
    # Crear el contenedor con scroll
    display(HTML(scroll_style + '<div class="scrollable-table">' + html + '</div>'))

# Diccionario de clasificación
clasificacion = {
    "Rating Alto (Confiable)": 1,
    "Rating Alto (Moderadamente confiable)": 2,
    "Rating Alto (Medio confiable)": 3,
    "Rating Alto (Poco confiable)": 4,
    "Rating Bajo (Confiable)": 5,
    "Rating Bajo (Moderadamente confiable)": 6,
    "Rating Bajo (Medio confiable)": 7,
    "Rating Bajo (Poco confiable)": 8,
}

# Aplicar la clasificación al DataFrame
amazon_unificado['rating_level'] = amazon_unificado['rating_segmentation'].map(clasificacion)

# Mostrar el DataFrame con la nueva columna usando el contenedor con scroll
display_with_scroll(amazon_unificado[['rating_segmentation', 'rating_level']], max_height='400px', max_width='50%')
# Out:
#     <style>
#         .scrollable-table {
#             max-height: 400px;
#             max-width: 50%;
#             overflow-y: auto;
#             overflow-x: auto;
#             display: block;
#             margin: 0 auto; /* Centra el contenedor horizontalmente */
#         }
#         .scrollable-table table {
#             width: 100%;
#         }
#     </style>
#     <div class="scrollable-table"><table border="1" class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th>rating_segmentation</th>
#       <th>rating_level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Rating Alto (Moderadamente confiable)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Rating Alto (Moderadamente confiable)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Rating Alto (Medio confiable)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Rating Alto (Moderadamente confiable)</td>
#       <td>2</td>
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot

# Clasificación de 'rating_segmentation' a 'rating_level'
clasificacion = {
    "Rating Alto (Confiable)": 1,
    "Rating Alto (Moderadamente confiable)": 2,
    "Rating Alto (Medio confiable)": 3,
    "Rating Alto (Poco confiable)": 4,
    "Rating Bajo (Confiable)": 5,
    "Rating Bajo (Moderadamente confiable)": 6,
    "Rating Bajo (Medio confiable)": 7,
    "Rating Bajo (Poco confiable)": 8,
}

# Aplicar la clasificación al DataFrame
amazon_unificado['rating_level'] = amazon_unificado['rating_segmentation'].map(clasificacion)

# Asegurarse de que las columnas 'rating_level' y 'rating_count' sean numéricas
amazon_unificado['rating_level'] = pd.to_numeric(amazon_unificado['rating_level'], errors='coerce')
amazon_unificado['rating_count'] = pd.to_numeric(amazon_unificado['rating_count'], errors='coerce')

# Paso 1: Identificación del Tipo de Variables
rating_level_is_numeric = pd.api.types.is_numeric_dtype(amazon_unificado['rating_level'])
rating_count_is_numeric = pd.api.types.is_numeric_dtype(amazon_unificado['rating_count'])

if rating_level_is_numeric and rating_count_is_numeric:
    variable_type = "Ambas variables son continuas y numéricas."
    print(f"Variables: 'rating_level' y 'rating_count' son continuas y numéricas.")

    # Paso 2: Evaluación de la Distribución de los Datos
    print("\nPaso 2: Evaluación de la Distribución de los Datos")

    # Test de normalidad para 'rating_level'
    rating_level_shapiro = stats.shapiro(amazon_unificado['rating_level'].dropna())
    print(f"Shapiro-Wilk Test para 'rating_level': p-valor = {rating_level_shapiro.pvalue:.4f}")

    # Test de normalidad para 'rating_count'
    rating_count_shapiro = stats.shapiro(amazon_unificado['rating_count'].dropna())
    print(f"Shapiro-Wilk Test para 'rating_count': p-valor = {rating_count_shapiro.pvalue:.4f}")

    # Visualización de la distribución
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(amazon_unificado['rating_level'].dropna(), kde=True, color='blue')
    plt.title('Distribución de Rating Level')

    plt.subplot(1, 2, 2)
    sns.histplot(amazon_unificado['rating_count'].dropna(), kde=True, color='green')
    plt.title('Distribución de Rating Count')
    plt.show()

    # Q-Q Plots para ver la normalidad
    qqplot(amazon_unificado['rating_level'].dropna(), line='s')
    plt.title('Q-Q Plot para Rating Level')
    plt.show()

    qqplot(amazon_unificado['rating_count'].dropna(), line='s')
    plt.title('Q-Q Plot para Rating Count')
    plt.show()

    # Paso 3: Selección del Test Estadístico
    print("\nPaso 3: Selección del Test Estadístico")
    if rating_level_shapiro.pvalue > 0.05 and rating_count_shapiro.pvalue > 0.05:
        # Ambas variables siguen una distribución normal
        print("Ambas variables siguen una distribución normal. Se utilizará el Test de Correlación de Pearson y el Test de Correlación de Kendall.")
        corr_test1 = "pearson"
        correlation1, p_value1 = stats.pearsonr(amazon_unificado['rating_level'].dropna(), amazon_unificado['rating_count'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating_level'].dropna(), amazon_unificado['rating_count'].dropna())
        
    else:
        # Al menos una variable no sigue una distribución normal
        print("Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.")
        corr_test1 = "spearman"
        correlation1, p_value1 = stats.spearmanr(amazon_unificado['rating_level'].dropna(), amazon_unificado['rating_count'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating_level'].dropna(), amazon_unificado['rating_count'].dropna())

    # Paso 4: Verificación de Supuestos y Resultados
    print("\nPaso 4: Verificación de Supuestos y Resultados")

    def describe_correlation(correlation):
        if correlation == 1:
            return "perfecta y positiva"
        elif correlation == -1:
            return "perfecta y negativa"
        elif 0.7 < correlation < 1:
            return "fuerte y positiva"
        elif -1 < correlation < -0.7:
            return "fuerte y negativa"
        elif 0.4 < correlation <= 0.7:
            return "moderada y positiva"
        elif -0.7 <= correlation < -0.4:
            return "moderada y negativa"
        elif 0.2 < correlation <= 0.4:
            return "débil y positiva"
        elif -0.4 <= correlation < -0.2:
            return "débil y negativa"
        else:
            return "muy débil"

    # Resultados del Test 1
    print(f"Test 1 Seleccionado: {corr_test1.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation1:.4f} ({describe_correlation(correlation1)})")
    print(f"p-valor: {p_value1:.4f}")
    if p_value1 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de {corr_test1.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de {corr_test1.capitalize()}.")

    # Resultados del Test 2
    print(f"\nTest 2 Seleccionado: {corr_test2.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation2:.4f} ({describe_correlation(correlation2)})")
    print(f"p-valor: {p_value2:.4f}")
    if p_value2 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de {corr_test2.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de {corr_test2.capitalize()}.")

else:
    print("Una o ambas variables no son numéricas. No se puede realizar la correlación.")
# Out:
# Variables: 'rating_level' y 'rating_count' son continuas y numéricas.
#
# Paso 2: Evaluación de la Distribución de los Datos
# Shapiro-Wilk Test para 'rating_level': p-valor = 0.0000
# Shapiro-Wilk Test para 'rating_count': p-valor = 0.0000
# Paso 3: Selección del Test Estadístico
# Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.
#
# Paso 4: Verificación de Supuestos y Resultados
# Test 1 Seleccionado: Spearman Correlation Test
# Coeficiente de Correlación: -0.7129 (fuerte y negativa)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de Spearman.
#
# Test 2 Seleccionado: Kendall Correlation Test
# Coeficiente de Correlación: -0.6016 (moderada y negativa)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating_level' y 'rating_count' según el test de Kendall.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse de que las columnas 'rating' y 'rating_count' sean numéricas
amazon_unificado['rating'] = pd.to_numeric(amazon_unificado['rating'], errors='coerce')
amazon_unificado['rating_count'] = pd.to_numeric(amazon_unificado['rating_count'], errors='coerce')

# Paso 1: Identificación del Tipo de Variables
rating_is_numeric = pd.api.types.is_numeric_dtype(amazon_unificado['rating'])
rating_count_is_integer = pd.api.types.is_integer_dtype(amazon_unificado['rating_count'])

if rating_is_numeric and rating_count_is_integer:
    variable_type = "Rating es continuo y Rating Count es entero."
    print(f"Variables: 'rating' es continuo y numérico, y 'rating_count' es entero.")

    # Paso 2: Evaluación de la Distribución de los Datos
    print("\nPaso 2: Evaluación de la Distribución de los Datos")

    # Test de normalidad para 'rating'
    rating_shapiro = stats.shapiro(amazon_unificado['rating'].dropna())
    print(f"Shapiro-Wilk Test para 'rating': p-valor = {rating_shapiro.pvalue:.4f}")

    # Test de normalidad para 'rating_count'
    rating_count_shapiro = stats.shapiro(amazon_unificado['rating_count'].dropna())
    print(f"Shapiro-Wilk Test para 'rating_count': p-valor = {rating_count_shapiro.pvalue:.4f}")

    # Visualización de la distribución
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(amazon_unificado['rating'].dropna(), kde=True, color='blue')
    plt.title('Distribución de Rating')

    plt.subplot(1, 2, 2)
    sns.histplot(amazon_unificado['rating_count'].dropna(), kde=True, color='green')
    plt.title('Distribución de Rating Count')
    plt.show()

    # Paso 3: Selección del Test Estadístico
    print("\nPaso 3: Selección del Test Estadístico")
    if rating_shapiro.pvalue > 0.05 and rating_count_shapiro.pvalue > 0.05:
        # Ambas variables siguen una distribución normal
        print("Ambas variables siguen una distribución normal. Se utilizará el Test de Correlación de Pearson y el Test de Correlación de Kendall.")
        corr_test1 = "pearson"
        correlation1, p_value1 = stats.pearsonr(amazon_unificado['rating'].dropna(), amazon_unificado['rating_count'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating'].dropna(), amazon_unificado['rating_count'].dropna())
        
    else:
        # Al menos una variable no sigue una distribución normal
        print("Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.")
        corr_test1 = "spearman"
        correlation1, p_value1 = stats.spearmanr(amazon_unificado['rating'].dropna(), amazon_unificado['rating_count'].dropna())

        # Test adicional: Kendall para comparación
        corr_test2 = "kendall"
        correlation2, p_value2 = stats.kendalltau(amazon_unificado['rating'].dropna(), amazon_unificado['rating_count'].dropna())

    # Paso 4: Verificación de Supuestos y Resultados
    print("\nPaso 4: Verificación de Supuestos y Resultados")

    def describe_correlation(correlation):
        if correlation == 1:
            return "perfecta y positiva"
        elif correlation == -1:
            return "perfecta y negativa"
        elif 0.7 < correlation < 1:
            return "fuerte y positiva"
        elif -1 < correlation < -0.7:
            return "fuerte y negativa"
        elif 0.4 < correlation <= 0.7:
            return "moderada y positiva"
        elif -0.7 <= correlation < -0.4:
            return "moderada y negativa"
        elif 0.2 < correlation <= 0.4:
            return "débil y positiva"
        elif -0.4 <= correlation < -0.2:
            return "débil y negativa"
        else:
            return "muy débil"

    # Resultados del Test 1
    print(f"Test 1 Seleccionado: {corr_test1.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation1:.4f} ({describe_correlation(correlation1)})")
    print(f"p-valor: {p_value1:.4f}")
    if p_value1 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de {corr_test1.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de {corr_test1.capitalize()}.")

    # Resultados del Test 2
    print(f"\nTest 2 Seleccionado: {corr_test2.capitalize()} Correlation Test")
    print(f"Coeficiente de Correlación: {correlation2:.4f} ({describe_correlation(correlation2)})")
    print(f"p-valor: {p_value2:.4f}")
    if p_value2 < 0.05:
        print(f"Existe una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de {corr_test2.capitalize()}.")
    else:
        print(f"No se encontró una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de {corr_test2.capitalize()}.")

    # Gráfico de dispersión con línea de tendencia
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='rating', y='rating_count', data=amazon_unificado, color='purple', s=50)
    sns.regplot(x='rating', y='rating_count', data=amazon_unificado, scatter=False, color='red')
    plt.title('Relación entre Rating y Rating Count')
    plt.xlabel('Rating')
    plt.ylabel('Rating Count')
    plt.show()

    # Gráfico de caja para Rating Count según Rating
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='rating', y='rating_count', data=amazon_unificado, hue='rating', palette='coolwarm', legend=False)
    plt.title('Distribución de Rating Count por Rating')
    plt.xlabel('Rating')
    plt.ylabel('Rating Count')
    plt.show()

else:
    print("Una o ambas variables no son numéricas. No se puede realizar la correlación.")
# Out:
# Variables: 'rating' es continuo y numérico, y 'rating_count' es entero.
#
# Paso 2: Evaluación de la Distribución de los Datos
# Shapiro-Wilk Test para 'rating': p-valor = 0.0000
# Shapiro-Wilk Test para 'rating_count': p-valor = 0.0000
# Paso 3: Selección del Test Estadístico
# Al menos una variable no sigue una distribución normal. Se utilizará el Test de Correlación de Spearman y el Test de Correlación de Kendall.
#
# Paso 4: Verificación de Supuestos y Resultados
# Test 1 Seleccionado: Spearman Correlation Test
# Coeficiente de Correlación: 0.1975 (muy débil)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de Spearman.
#
# Test 2 Seleccionado: Kendall Correlation Test
# Coeficiente de Correlación: 0.1411 (muy débil)
# p-valor: 0.0000
# Existe una correlación estadísticamente significativa entre 'rating' y 'rating_count' según el test de Kendall.

# %%
# Número total de filas y columnas en el DataFrame
num_filas, num_columnas = amazon_unificado.shape
print(f"Número de filas: {num_filas}")
print(f"Número de columnas: {num_columnas}")

# Número total de datos (es decir, el producto del número de filas y columnas)
total_datos = num_filas * num_columnas
print(f"Número total de datos en el DataFrame: {total_datos}")

# Alternativamente, puedes usar len() para contar solo las filas
num_filas = len(amazon_unificado)
print(f"Número de filas: {num_filas}")
# Out:
# Número de filas: 1170
# Número de columnas: 22
# Número total de datos en el DataFrame: 25740
# Número de filas: 1170

# %% [markdown]
# # Inicio calculos de Riesgo Relativo

# %%
import pandas as pd

# Supongamos que 'amazon_unificado' es tu DataFrame
# Agrupamos por 'general_category' y 'category_rating' y contamos las ocurrencias
categoria_counts = amazon_unificado.groupby(['general_category', 'category_rating']).size().reset_index(name='count')

# Pivotamos el DataFrame para obtener un formato con categorías como columnas
pivot_table = categoria_counts.pivot_table(index='general_category', columns='category_rating', values='count', fill_value=0)

# Mostrar el DataFrame resultante
pivot_table
# Out:
# category_rating         Alto   Bajo
# general_category
# Car&Motorbike            0.0    1.0
# Computers&Accessories  258.0   61.0
# Electronics            253.0  116.0
# Health&PersonalCare      1.0    0.0
# Home&Kitchen           301.0  143.0
# HomeImprovement          2.0    0.0
# MusicalInstruments       1.0    1.0
# OfficeProducts          31.0    0.0
# Toys&Games               1.0    0.0

# %% [markdown]
# # Cuartiles de Actual price

# %%
import pandas as pd

# Supongamos que tu DataFrame se llama amazon_unificado y ya está cargado
# Asegúrate de que actual_price sea numérico
amazon_unificado['actual_price'] = pd.to_numeric(amazon_unificado['actual_price'], errors='coerce')

# Calcular los cuartiles
quartiles = amazon_unificado['actual_price'].quantile([0.25, 0.5, 0.75])

# Crear las categorías de cuartiles
amazon_unificado['Categoría'] = pd.cut(amazon_unificado['actual_price'], bins=[0, quartiles[0.25], quartiles[0.5], quartiles[0.75], float('inf')],
                                       labels=[f'Menor a {quartiles[0.25]:.2f}',
                                               f'Menor a {quartiles[0.50]:.2f}',
                                               f'Menor a {quartiles[0.75]:.2f}',
                                               f'Mayores de {quartiles[0.75]:.2f}'],
                                       include_lowest=True)

# Contar los datos en cada categoría
conteo_cuartiles = amazon_unificado.groupby('Categoría').size().reset_index(name='Conteo')

# Mostrar los resultados
print(conteo_cuartiles)
# Out:
#             Categoría  Conteo
# 0      Menor a 880.00     293
# 1     Menor a 1695.00     293
# 2     Menor a 3990.00     296
# 3  Mayores de 3990.00     288
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_4172\380456575.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   conteo_cuartiles = amazon_unificado.groupby('Categoría').size().reset_index(name='Conteo')

# %% [markdown]
# # Riesgo relativo de Categoria de productos

# %%
import pandas as pd
from IPython.display import display

# Supongamos que tu DataFrame se llama amazon_unificado y ya está cargado

# Crear una lista de categorías únicas
categorias = amazon_unificado['general_category'].unique()

# Crear una lista para almacenar los DataFrames de cada categoría
resultados_categorias = []

# Función para aplicar formato a la razón
def highlight_reason(val):
    if isinstance(val, (int, float)) and val > 1:
        return 'background-color: lightcoral; color: white; font-weight: bold'
    return ''

# Calcular los resultados para cada categoría
for categoria in categorias:
    # Filtrar los datos para la categoría actual
    df_categoria = amazon_unificado[amazon_unificado['general_category'] == categoria]
    
    # Contar los valores de category_rating
    conteo_alto = df_categoria[df_categoria['category_rating'] == 'Alto'].shape[0]
    conteo_bajo = df_categoria[df_categoria['category_rating'] == 'Bajo'].shape[0]
    
    # Calcular el total y la proporción de "Bajo"
    total = conteo_alto + conteo_bajo
    proporcion_bajo = conteo_bajo / total if total > 0 else 0
    
    # Calcular el conteo global de otras categorías
    df_otros = amazon_unificado[amazon_unificado['general_category'] != categoria]
    conteo_alto_otros = df_otros[df_otros['category_rating'] == 'Alto'].shape[0]
    conteo_bajo_otros = df_otros[df_otros['category_rating'] == 'Bajo'].shape[0]
    total_otros = conteo_alto_otros + conteo_bajo_otros
    proporcion_bajo_otros = conteo_bajo_otros / total_otros if total_otros > 0 else 0
    
    # Calcular la razón
    razon_proporcion = proporcion_bajo / proporcion_bajo_otros if proporcion_bajo_otros > 0 else 0
    
    # Crear un DataFrame para la categoría actual
    resultados_categoria = pd.DataFrame({
        'Categoría': [categoria],
        'Conteo Alto': [conteo_alto],
        'Conteo Bajo': [conteo_bajo],
        'Total': [total],
        'Proporción Bajo': [proporcion_bajo]
    })
    
    # Crear un DataFrame para las demás categorías combinadas
    resultados_otros = pd.DataFrame({
        'Categoría': ['Todas las demás categorías'],
        'Conteo Alto': [conteo_alto_otros],
        'Conteo Bajo': [conteo_bajo_otros],
        'Total': [total_otros],
        'Proporción Bajo': [proporcion_bajo_otros]
    })
    
    # Crear un DataFrame para la razón
    resultados_razon = pd.DataFrame({
        'Categoría': ['Razón'],
        'Conteo Alto': [''],
        'Conteo Bajo': [''],
        'Total': [''],
        'Proporción Bajo': [razon_proporcion]
    })
    
    # Concatenar los DataFrames de la categoría, las demás categorías y la razón
    resultado_completo = pd.concat([resultados_categoria, resultados_otros, resultados_razon], ignore_index=True)
    
    # Aplicar el estilo condicional usando map
    styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
    
    # Agregar los DataFrames a la lista de resultados de categorías
    resultados_categorias.append(styled_resultado)

# Mostrar los resultados de cada categoría en Jupyter Notebook
for styled_df in resultados_categorias:
    display(styled_df)
# Out:
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_4172\3607772892.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
# <style type="text/css">
# #T_a5d4e_row2_col4 {
#   background-color: lightcoral;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_a5d4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5d4e_level0_col0" class="col_heading level0 col0" >Categoría</th>
#       <th id="T_a5d4e_level0_col1" class="col_heading level0 col1" >Conteo Alto</th>
#       <th id="T_a5d4e_level0_col2" class="col_heading level0 col2" >Conteo Bajo</th>
#       <th id="T_a5d4e_level0_col3" class="col_heading level0 col3" >Total</th>
#       <th id="T_a5d4e_level0_col4" class="col_heading level0 col4" >Proporción Bajo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # Riesgo Relativo -- Descuento

# %%
import pandas as pd
from IPython.display import display

# Supongamos que tu DataFrame se llama amazon_unificado y ya está cargado

# Crear una lista de categorías únicas para category_discount
descuentos = amazon_unificado['category_discount'].unique()

# Crear una lista para almacenar los DataFrames de cada descuento
resultados_descuentos = []

# Función para aplicar formato a la razón
def highlight_reason(val):
    if isinstance(val, (int, float)) and val > 1:
        return 'background-color: lightcoral; color: white; font-weight: bold'
    return ''

# Calcular los resultados para cada descuento
for descuento in descuentos:
    # Filtrar los datos para el descuento actual
    df_descuento = amazon_unificado[amazon_unificado['category_discount'] == descuento]
    
    # Contar los valores de category_rating
    conteo_alto = df_descuento[df_descuento['category_rating'] == 'Alto'].shape[0]
    conteo_bajo = df_descuento[df_descuento['category_rating'] == 'Bajo'].shape[0]
    
    # Calcular el total y la proporción de "Bajo"
    total = conteo_alto + conteo_bajo
    proporcion_bajo = conteo_bajo / total if total > 0 else 0
    
    # Calcular el conteo global de otros descuentos
    df_otros = amazon_unificado[amazon_unificado['category_discount'] != descuento]
    conteo_alto_otros = df_otros[df_otros['category_rating'] == 'Alto'].shape[0]
    conteo_bajo_otros = df_otros[df_otros['category_rating'] == 'Bajo'].shape[0]
    total_otros = conteo_alto_otros + conteo_bajo_otros
    proporcion_bajo_otros = conteo_bajo_otros / total_otros if total_otros > 0 else 0
    
    # Calcular la razón
    razon_proporcion = proporcion_bajo / proporcion_bajo_otros if proporcion_bajo_otros > 0 else 0
    
    # Crear un DataFrame para el descuento actual
    resultados_descuento = pd.DataFrame({
        'Descuento': [descuento],
        'Conteo Alto': [conteo_alto],
        'Conteo Bajo': [conteo_bajo],
        'Total': [total],
        'Proporción Bajo': [proporcion_bajo]
    })
    
    # Crear un DataFrame para los demás descuentos combinados
    resultados_otros = pd.DataFrame({
        'Descuento': ['Todos los demás descuentos'],
        'Conteo Alto': [conteo_alto_otros],
        'Conteo Bajo': [conteo_bajo_otros],
        'Total': [total_otros],
        'Proporción Bajo': [proporcion_bajo_otros]
    })
    
    # Crear un DataFrame para la razón
    resultados_razon = pd.DataFrame({
        'Descuento': ['Razón'],
        'Conteo Alto': [''],
        'Conteo Bajo': [''],
        'Total': [''],
        'Proporción Bajo': [razon_proporcion]
    })
    
    # Concatenar los DataFrames del descuento, los demás descuentos y la razón
    resultado_completo = pd.concat([resultados_descuento, resultados_otros, resultados_razon], ignore_index=True)
    
    # Aplicar el estilo condicional usando map
    styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
    
    # Agregar los DataFrames a la lista de resultados de descuentos
    resultados_descuentos.append(styled_resultado)

# Mostrar los resultados de cada descuento en Jupyter Notebook
for styled_df in resultados_descuentos:
    display(styled_df)
# Out:
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_4172\2897714873.py:72: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
# <style type="text/css">
# #T_eeaa5_row2_col4 {
#   background-color: lightcoral;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_eeaa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeaa5_level0_col0" class="col_heading level0 col0" >Descuento</th>
#       <th id="T_eeaa5_level0_col1" class="col_heading level0 col1" >Conteo Alto</th>
#       <th id="T_eeaa5_level0_col2" class="col_heading level0 col2" >Conteo Bajo</th>
#       <th id="T_eeaa5_level0_col3" class="col_heading level0 col3" >Total</th>
#       <th id="T_eeaa5_level0_col4" class="col_heading level0 col4" >Proporción Bajo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # Riesgo relativo - Actual price

# %%
import pandas as pd
from IPython.display import display

# Supongamos que tu DataFrame se llama amazon_unificado y ya está cargado

# Calcular los cuartiles para actual_price
quartiles = amazon_unificado['actual_price'].quantile([0.25, 0.50, 0.75]).values

# Crear etiquetas para los cuartiles
labels = [
    f'Menor a {quartiles[0]:.2f}',
    f'Menor a {quartiles[1]:.2f}',
    f'Menor a {quartiles[2]:.2f}',
    f'Mayores de {quartiles[2]:.2f}'
]

# Crear una lista para almacenar los DataFrames de cada cuartil
resultados_cuartiles = []

# Función para aplicar formato a la razón
def highlight_reason(val):
    if isinstance(val, (int, float)) and val > 1:
        return 'background-color: lightcoral; color: white; font-weight: bold'
    return ''

# Calcular los resultados para cada cuartil
for i, label in enumerate(labels):
    # Determinar el rango para el cuartil actual
    if i == 0:
        df_cuartil = amazon_unificado[amazon_unificado['actual_price'] <= quartiles[0]]
    elif i == 1:
        df_cuartil = amazon_unificado[(amazon_unificado['actual_price'] > quartiles[0]) & (amazon_unificado['actual_price'] <= quartiles[1])]
    elif i == 2:
        df_cuartil = amazon_unificado[(amazon_unificado['actual_price'] > quartiles[1]) & (amazon_unificado['actual_price'] <= quartiles[2])]
    else:
        df_cuartil = amazon_unificado[amazon_unificado['actual_price'] > quartiles[2]]
    
    # Contar los valores de category_rating
    conteo_alto = df_cuartil[df_cuartil['category_rating'] == 'Alto'].shape[0]
    conteo_bajo = df_cuartil[df_cuartil['category_rating'] == 'Bajo'].shape[0]
    
    # Calcular el total y la proporción de "Bajo"
    total = conteo_alto + conteo_bajo
    proporcion_bajo = conteo_bajo / total if total > 0 else 0
    
    # Calcular el conteo global de otros cuartiles
    df_otros = amazon_unificado[~amazon_unificado.index.isin(df_cuartil.index)]
    conteo_alto_otros = df_otros[df_otros['category_rating'] == 'Alto'].shape[0]
    conteo_bajo_otros = df_otros[df_otros['category_rating'] == 'Bajo'].shape[0]
    total_otros = conteo_alto_otros + conteo_bajo_otros
    proporcion_bajo_otros = conteo_bajo_otros / total_otros if total_otros > 0 else 0
    
    # Calcular la razón
    razon_proporcion = proporcion_bajo / proporcion_bajo_otros if proporcion_bajo_otros > 0 else 0
    
    # Crear un DataFrame para el cuartil actual
    resultados_cuartil = pd.DataFrame({
        'Rango de Precio': [label],
        'Conteo Alto': [conteo_alto],
        'Conteo Bajo': [conteo_bajo],
        'Total': [total],
        'Proporción Bajo': [proporcion_bajo]
    })
    
    # Crear un DataFrame para los demás cuartiles combinados
    resultados_otros = pd.DataFrame({
        'Rango de Precio': ['Todos los demás cuartiles'],
        'Conteo Alto': [conteo_alto_otros],
        'Conteo Bajo': [conteo_bajo_otros],
        'Total': [total_otros],
        'Proporción Bajo': [proporcion_bajo_otros]
    })
    
    # Crear un DataFrame para la razón
    resultados_razon = pd.DataFrame({
        'Rango de Precio': ['Razón'],
        'Conteo Alto': [''],
        'Conteo Bajo': [''],
        'Total': [''],
        'Proporción Bajo': [razon_proporcion]
    })
    
    # Concatenar los DataFrames del cuartil, los demás cuartiles y la razón
    resultado_completo = pd.concat([resultados_cuartil, resultados_otros, resultados_razon], ignore_index=True)
    
    # Aplicar el estilo condicional usando map
    styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
    
    # Agregar los DataFrames a la lista de resultados de cuartiles
    resultados_cuartiles.append(styled_resultado)

# Mostrar los resultados de cada cuartil en Jupyter Notebook
for styled_df in resultados_cuartiles:
    display(styled_df)
# Out:
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_4172\1531445558.py:87: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
# <style type="text/css">
# #T_72326_row2_col4 {
#   background-color: lightcoral;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_72326">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72326_level0_col0" class="col_heading level0 col0" >Rango de Precio</th>
#       <th id="T_72326_level0_col1" class="col_heading level0 col1" >Conteo Alto</th>
#       <th id="T_72326_level0_col2" class="col_heading level0 col2" >Conteo Bajo</th>
#       <th id="T_72326_level0_col3" class="col_heading level0 col3" >Total</th>
#       <th id="T_72326_level0_col4" class="col_heading level0 col4" >Proporción Bajo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # riesgo discounted price

# %%
import pandas as pd
from IPython.display import display

# Supongamos que tu DataFrame se llama amazon_unificado y ya está cargado

# Asegúrate de que discounted_price sea numérico
amazon_unificado['discounted_price'] = pd.to_numeric(amazon_unificado['discounted_price'], errors='coerce')

# Calcular los cuartiles para discounted_price
quartiles = amazon_unificado['discounted_price'].quantile([0.25, 0.50, 0.75]).values

# Crear etiquetas para los cuartiles
labels = [
    f'Menor a {quartiles[0]:.2f}',
    f'Menor a {quartiles[1]:.2f}',
    f'Menor a {quartiles[2]:.2f}',
    f'Mayores de {quartiles[2]:.2f}'
]

# Crear una lista para almacenar los DataFrames de cada cuartil
resultados_cuartiles = []

# Función para aplicar formato a la razón
def highlight_reason(val):
    if isinstance(val, (int, float)) and val > 1:
        return 'background-color: lightcoral; color: white; font-weight: bold'
    return ''

# Calcular los resultados para cada cuartil
for i, label in enumerate(labels):
    # Determinar el rango para el cuartil actual
    if i == 0:
        df_cuartil = amazon_unificado[amazon_unificado['discounted_price'] <= quartiles[0]]
    elif i == 1:
        df_cuartil = amazon_unificado[(amazon_unificado['discounted_price'] > quartiles[0]) & (amazon_unificado['discounted_price'] <= quartiles[1])]
    elif i == 2:
        df_cuartil = amazon_unificado[(amazon_unificado['discounted_price'] > quartiles[1]) & (amazon_unificado['discounted_price'] <= quartiles[2])]
    else:
        df_cuartil = amazon_unificado[amazon_unificado['discounted_price'] > quartiles[2]]
    
    # Contar los valores de category_rating
    conteo_alto = df_cuartil[df_cuartil['category_rating'] == 'Alto'].shape[0]
    conteo_bajo = df_cuartil[df_cuartil['category_rating'] == 'Bajo'].shape[0]
    
    # Calcular el total y la proporción de "Bajo"
    total = conteo_alto + conteo_bajo
    proporcion_bajo = conteo_bajo / total if total > 0 else 0
    
    # Calcular el conteo global de otros cuartiles
    df_otros = amazon_unificado[~amazon_unificado.index.isin(df_cuartil.index)]
    conteo_alto_otros = df_otros[df_otros['category_rating'] == 'Alto'].shape[0]
    conteo_bajo_otros = df_otros[df_otros['category_rating'] == 'Bajo'].shape[0]
    total_otros = conteo_alto_otros + conteo_bajo_otros
    proporcion_bajo_otros = conteo_bajo_otros / total_otros if total_otros > 0 else 0
    
    # Calcular la razón
    razon_proporcion = proporcion_bajo / proporcion_bajo_otros if proporcion_bajo_otros > 0 else 0
    
    # Crear un DataFrame para el cuartil actual
    resultados_cuartil = pd.DataFrame({
        'Rango de Precio': [label],
        'Conteo Alto': [conteo_alto],
        'Conteo Bajo': [conteo_bajo],
        'Total': [total],
        'Proporción Bajo': [proporcion_bajo]
    })
    
    # Crear un DataFrame para los demás cuartiles combinados
    resultados_otros = pd.DataFrame({
        'Rango de Precio': ['Todos los demás cuartiles'],
        'Conteo Alto': [conteo_alto_otros],
        'Conteo Bajo': [conteo_bajo_otros],
        'Total': [total_otros],
        'Proporción Bajo': [proporcion_bajo_otros]
    })
    
    # Crear un DataFrame para la razón
    resultados_razon = pd.DataFrame({
        'Rango de Precio': ['Razón'],
        'Conteo Alto': [''],
        'Conteo Bajo': [''],
        'Total': [''],
        'Proporción Bajo': [razon_proporcion]
    })
    
    # Concatenar los DataFrames del cuartil, los demás cuartiles y la razón
    resultado_completo = pd.concat([resultados_cuartil, resultados_otros, resultados_razon], ignore_index=True)
    
    # Aplicar el estilo condicional usando map
    styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
    
    # Agregar los DataFrames a la lista de resultados de cuartiles
    resultados_cuartiles.append(styled_resultado)

# Mostrar los resultados de cada cuartil en Jupyter Notebook
for styled_df in resultados_cuartiles:
    display(styled_df)
# Out:
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_24284\3733210514.py:90: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_resultado = resultado_completo.style.applymap(highlight_reason, subset=['Proporción Bajo'])
# <style type="text/css">
# #T_f3451_row2_col4 {
#   background-color: lightcoral;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_f3451">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3451_level0_col0" class="col_heading level0 col0" >Rango de Precio</th>
#       <th id="T_f3451_level0_col1" class="col_heading level0 col1" >Conteo Alto</th>
#       <th id="T_f3451_level0_col2" class="col_heading level0 col2" >Conteo Bajo</th>
#       <th id="T_f3451_level0_col3" class="col_heading level0 col3" >Total</th>
#       <th id="T_f3451_level0_col4" class="col_heading level0 col4" >Proporción Bajo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # cohort, inicio

# %% [markdown]
# ## Rating

# %%
# Crear el mapeo de categorías
category_mapping = {
    'Electronics': [
        'USBCables', 'RemoteControls', 'In-Ear', 'SmartWatches', 'SmartTelevisions', 
        'Smartphones', 'Mice', 'HDMICables', 'WallChargers', 'ScreenProtectors', 
        'GraphicTablets', 'WirelessUSBAdapters', 'PenDrives', 'Routers', 
        'ExternalHardDisks', 'BluetoothSpeakers', 'TVWall&CeilingMounts', 
        'Lamps', 'Headsets', 'Projectors', 'Webcams', 'Monitors', 'PCSpeakers',
        'VideoCameras', 'PowerBanks', 'AVReceivers&Amplifiers', 'SelfieSticks', 
        'Printers', 'SatelliteReceivers', 'Humidifiers', 'Condenser', 'ExternalMemoryCardReaders', 
        'EthernetCables', 'CameraPrivacyCovers', 'DigitalScales', 'Scientific', 
        'PCMicrophones', 'USBtoUSBAdapters', 'Over-Ear', 'OTGAdapters'
    ],
    'Kitchen Appliances': [
        'MixerGrinders', 'DryIrons', 'InstantWaterHeaters', 'LintShavers', 
        'ElectricHeaters', 'ElectricKettles', 'FanHeaters', 'HandBlenders', 
        'JuicerMixerGrinders', 'SteamIrons', 'SandwichMakers', 'EggBoilers', 
        'InductionCooktop', 'ImmersionRods', 'DigitalKitchenScales', 'AirFryers', 
        'DripCoffeeMachines', 'Pop-upToasters', 'MilkFrothers', 'ColdPressJuicers', 
        'HandMixers', 'WaffleMakers&Irons', 'OvenToasterGrills', 'Rice&PastaCookers', 
        'EspressoMachines', 'ElectricGrinders', 'RotiMakers', 'StovetopEspressoPots', 
        'YogurtMakers', 'Juicers', 'SteamIrons', 'ElectricHeaters'
    ],
    'Home Appliances': [
        'CeilingFans', 'WaterFilters&Purifiers', 'StorageWaterHeaters', 
        'WaterPurifierAccessories', 'ExhaustFans', 'PressureWashers,Steam&WindowCleaners', 
        'RoboticVacuums', 'WetGrinders', 'RoomHeaters', 'HalogenHeaters', 'HeatConvectors', 
        'AirPurifiers&Ionizers', 'FanParts&Accessories', 'TableFans', 'PedestalFans', 
        'SmallKitchenAppliances', 'StandMixers', 'SteamIrons'
    ],
    'Computing Accessories': [
        'Lapdesks', 'Keyboard&MouseSets', 'Laptops', 'MousePads', 
        'Notebooks,WritingPads&Diaries', 'USBHubs', 'Tablets', 'SurgeProtectors',
        'NetworkingDevices', 'CoolingPads', 'LaptopChargers&PowerSupplies', 
        'InternalHardDrives', 'InkjetPrinters', 'SATA Cables', 'Cable Connection Protectors'
    ],
    'Office Supplies': [
        'CompositionNotebooks', 'DisposableBatteries', 'Notepads&MemoBooks', 
        'CompleteTripodUnits', 'WoodenPencils', 'StickBallpointPens', 
        'GelInkRollerballPens', 'SprayBottles', 'DomeCameras', 'DustCovers', 
        'ExternalSolidStateDrives', 'InternalSolidStateDrives', 'BottledInk',
        'Financial&Business', 'BasicCases', 'Scientific'
    ],
    'Gaming': [
        'Gamepads', 'GamingMice', 'GamingKeyboards', 'Routers', 
        'ExternalHardDisks', 'Printers', 'Projectors', 'StylusPens', 'Notepads'
    ],
    'Audio Accessories': [
        'BluetoothSpeakers', 'StylusPens', 'AirFryers', 'OTGAdapters', 
        'CanisterVacuums', 'MultimediaSpeakerSystems', 'Pop-upToasters'
    ],
    'Wearable Technology': [
        'SmartWatches', 'Headsets', 'In-Ear', 'Over-Ear', 
        'BasicMobiles', 'SelfieLights', 'BluetoothSpeakers', 'EthernetCables', 
        'Tripods', 'Macro&RinglightFlashes', 'Cradles', 'PhoneCharms'
    ],
    'Power Supplies': [
        'BatteryChargers', 'PowerLANAdapters', 'Adapters', 'SurgeProtectors',
        'Charging Stations', 'PowerBanks', 'Adapters&Multi-Outlets', 'UninterruptedPowerSupplies'
    ],
    'Data Storage': [
        'Memory', 'ExternalSolidStateDrives', 'ExternalHardDisks', 
        'USBHubs', 'PenDrives', 'InternalSolidStateDrives', 'MemoryCards'
    ],
    'Kitchenware': [
        'Juicers', 'DripCoffeeMachines', 'CoffeePresses', 'MilkFrothers', 
        'ColdPressJuicers', 'Caddies', 'MixerGrinders', 'LintShavers', 
        'HandheldVacuums', 'Sewing&EmbroideryMachines', 'Kitchen Storage'
    ],
    'Health & Personal Care': [
        'HandheldVacuums', 'ElectricKettles', 'MilkFrothers', 'AirPurifiers&Ionizers', 
        'PowerLANAdapters', 'TableFans', 'VacuumSealers', 'RoomHeaters', 
        'PersonalCareAppliances', 'MeasuringSpoons', 'MassageDevices'
    ],
    'Cleaning Appliances': [
        'HandheldVacuums', 'RoboticVacuums', 'CanisterVacuums', 'Wet-DryVacuums', 
        'SteamCleaners', 'PressureWashers', 'WindowCleaners', 'ImmersionRods'
    ],
    'Security & Surveillance': [
        'DomeCameras', 'WirelessSecurityCameras', 'SelfieSticks', 'CameraPrivacyCovers', 
        'Macro&RinglightFlashes', 'SurveillanceSystems', 'SecurityAlarms'
    ],
    'Networking': [
        'PowerLANAdapters', 'Routers', 'NetworkingDevices', 'USBAdapters', 
        'Repeaters&Extenders', 'AVReceivers&Amplifiers', 'ChargingStations'
    ],
    'Pet Supplies': [
        'AutomaticFeeders', 'PetBowls', 'PetGrooming', 'PetLeashes', 
        'PetCarriers', 'PetBeds', 'PetToilets', 'PetCleaning'
    ],
    'Stationery & Art Supplies': [
        'ColouredPaper', 'ColouringPens&Markers', 'Staplers', 'StickyNotes', 
        'Highlighters', 'Paints', 'Notebooks', 'SketchPads'
    ],
    'Fashion Accessories': [
        'StylusPens', 'Sewing&EmbroideryMachines', 'HandheldBags', 'Bags', 
        'Wallets', 'TravelAccessories', 'Belts', 'Watches'
    ],
    'Automotive': [
        'CarAccessories', 'MotorcycleAccessories', 'CarInteriorAccessories', 
        'AutomobileChargers', 'BatteryChargers', 'CarCleaningKits', 'MotorcycleHelmets'
    ],
    'Baby Products': [
        'BabyMonitors', 'Cribs', 'Playpens', 'BabyCarriers', 
        'Strollers', 'BabyBottles', 'BabyCarriers', 'ChangingMats'
    ],
    'Home Décor': [
        'Cushions&Throws', 'WallArt', 'Lighting', 'Mirrors', 
        'TableLamps', 'PictureFrames', 'WallClocks', 'Vases'
    ],
    'Jewellery': [
        'Necklaces', 'Earrings', 'Bracelets', 'Watches', 
        'Rings', 'JewelleryBoxes', 'JewelleryCleaningKits', 'JewelleryRepairKits'
    ],
    'Sports & Fitness': [
        'ExerciseEquipment', 'CampingGear', 'SportsShoes', 
        'FitnessTech', 'OutdoorGames', 'Cycling', 'Skiing&Snowboarding'
    ],
    'Tools': [
        'PowerTools', 'HandTools', 'MeasuringTools', 'WorkshopTools', 
        'ToolStorage', 'WeldingTools', 'ToolKits', 'GardenTools'
    ],
    'Beauty Products': [
        'Skincare', 'Make-up', 'Haircare', 'Perfumes', 
        'OralCare', 'NailCare', 'HairColoring', 'Men’sGrooming'
    ],
    'Home Improvement': [
        'Lighting', 'DoorHardware&Locks', 'BathroomHardware', 
        'Paint', 'Electrical', 'Flooring', 'OutdoorFurniture'
    ]
}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Asegúrate de que la variable 'rating' sea de tipo numérico
amazon_unificado['rating'] = pd.to_numeric(amazon_unificado['rating'], errors='coerce')


# Asignar la categoría secundaria en base a specific_category
def assign_second_category(specific_category):
    for second_category, categories in category_mapping.items():
        if specific_category in categories:
            return second_category
    return 'Others'  # Para categorías no asignadas

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(assign_second_category)

# Verifica si hay categorías no asignadas
print(amazon_unificado['second_category'].value_counts())

# Calcular el promedio de rating agrupado por general_category y second_category
df_pivot = amazon_unificado.pivot_table(
    values='rating', 
    index=['general_category', 'second_category'], 
    aggfunc='mean'
).reset_index()

# Verifica el DataFrame pivoteado
print(df_pivot.head())

# Pivotar los datos
heatmap_data = df_pivot.pivot(index='general_category', columns='second_category', values='rating')

# Configurar colores personalizados
def create_custom_colormap():
    colors = ['#FF0000', '#FFFF00', '#00FF00']  # Rojo, Amarillo, Verde
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)
    return cmap

# Crear una máscara para los valores NaN
mask = heatmap_data == 0 

# Crear el gráfico de calor
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt='.2f', cbar_kws={'label': 'Rating'}, linewidths=0.5)

# Configurar los colores para los NaN
plt.gca().set_facecolor('lightgrey')

plt.title('Heatmap de Ratings por Categoría General y Segunda Categoría')
plt.show()
# Out:
# second_category
# Electronics                  486
# Kitchen Appliances           285
# Others                       155
# Home Appliances               69
# Computing Accessories         51
# Office Supplies               43
# Gaming                        16
# Kitchenware                   13
# Wearable Technology           12
# Health & Personal Care        10
# Cleaning Appliances            6
# Stationery & Art Supplies      5
# Audio Accessories              5
# Power Supplies                 5
# Automotive                     4
# Networking                     3
# Data Storage                   1
# Fashion Accessories            1
# Name: count, dtype: int64
#         general_category        second_category    rating
# 0          Car&Motorbike        Home Appliances  3.800000
# 1  Computers&Accessories  Computing Accessories  4.087755
# 2  Computers&Accessories           Data Storage  4.500000
# 3  Computers&Accessories            Electronics  4.142857
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Asegúrate de que la variable 'rating' sea de tipo numérico
amazon_unificado['rating'] = pd.to_numeric(amazon_unificado['rating'], errors='coerce')

# Asignar la categoría secundaria en base a specific_category
def assign_second_category(specific_category):
    for second_category, categories in category_mapping.items():
        if specific_category in categories:
            return second_category
    return 'Others'  # Para categorías no asignadas

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(assign_second_category)

# Calcular el promedio de rating agrupado por general_category y second_category
df_pivot = amazon_unificado.pivot_table(
    values='rating', 
    index=['general_category', 'second_category'], 
    aggfunc='max'
).reset_index()

# Pivotar los datos
heatmap_data = df_pivot.pivot(index='general_category', columns='second_category', values='rating')

# Configurar colores personalizados
def create_custom_colormap():
    colors = ['#FF0000', '#FFFF00', '#00FF00']  # Rojo, Amarillo, Verde
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)
    return cmap

# Obtener el colormap personalizado
cmap = create_custom_colormap()

# Crear una máscara para los valores NaN
mask = heatmap_data == 0 

# Crear el gráfico de calor
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt='.2f', cbar_kws={'label': 'Rating'}, linewidths=0.5)

# Configurar los colores para los NaN
plt.gca().set_facecolor('lightgrey')

plt.title('Heatmap de Ratings por Categoría General y Segunda Categoría')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Asegúrate de que la variable 'rating' sea de tipo numérico
amazon_unificado['rating'] = pd.to_numeric(amazon_unificado['rating'], errors='coerce')


# Asignar la categoría secundaria en base a specific_category
def assign_second_category(specific_category):
    for second_category, categories in category_mapping.items():
        if specific_category in categories:
            return second_category
    return 'Others'  # Para categorías no asignadas

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(assign_second_category)


# Calcular el promedio de rating agrupado por general_category y second_category
df_pivot = amazon_unificado.pivot_table(
    values='rating', 
    index=['general_category', 'second_category'], 
    aggfunc='min'
).reset_index()


# Pivotar los datos
heatmap_data = df_pivot.pivot(index='general_category', columns='second_category', values='rating')

# Configurar colores personalizados
def create_custom_colormap():
    colors = ['#FF0000', '#FFFF00', '#00FF00']  # Rojo, Amarillo, Verde
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)
    return cmap

# Crear una máscara para los valores NaN
mask = heatmap_data == 0 

# Crear el gráfico de calor
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt='.2f', cbar_kws={'label': 'Rating'}, linewidths=0.5)

# Configurar los colores para los NaN
plt.gca().set_facecolor('lightgrey')

plt.title('Heatmap de Ratings por Categoría General y Segunda Categoría')
plt.show()

# %% [markdown]
# ## Actual Price

# %%
# Asegúrate de que 'actual_price' sea de tipo numérico
amazon_unificado['actual_price'] = pd.to_numeric(amazon_unificado['actual_price'], errors='coerce')

# Asignar la categoría secundaria en base a specific_category
def assign_second_category(specific_category):
    for second_category, categories in category_mapping.items():
        if specific_category in categories:
            return second_category
    return 'Others'  # Para categorías no asignadas

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(assign_second_category)

# Crear la figura con 3 subplots
fig, axes = plt.subplots(3, 1, figsize=(14, 18))

# Definir el mapeo de colores personalizado
def create_custom_colormap():
    colors = ['#FF0000', '#FFFF00', '#00FF00']  # Rojo, Amarillo, Verde
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)
    return cmap

# Calcular el mínimo y graficar
df_pivot_min = amazon_unificado.pivot_table(
    values='actual_price', 
    index=['general_category', 'second_category'], 
    aggfunc='min'
).reset_index()
heatmap_data_min = df_pivot_min.pivot(index='general_category', columns='second_category', values='actual_price')

sns.heatmap(
    heatmap_data_min, 
    annot=True, 
    cmap=create_custom_colormap(), 
    fmt='.2f', 
    cbar_kws={'label': 'Actual Price (Min)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[0]
)
axes[0].set_title('Min Actual Price')

# Calcular el máximo y graficar
df_pivot_max = amazon_unificado.pivot_table(
    values='actual_price', 
    index=['general_category', 'second_category'], 
    aggfunc='max'
).reset_index()
heatmap_data_max = df_pivot_max.pivot(index='general_category', columns='second_category', values='actual_price')

sns.heatmap(
    heatmap_data_max, 
    annot=True, 
    cmap=create_custom_colormap(), 
    fmt='.2f', 
    cbar_kws={'label': 'Actual Price (Max)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[1]
)
axes[1].set_title('Maximo Actual Price')

# Calcular el promedio y graficar
df_pivot_mean = amazon_unificado.pivot_table(
    values='actual_price', 
    index=['general_category', 'second_category'], 
    aggfunc='mean'
).reset_index()
heatmap_data_mean = df_pivot_mean.pivot(index='general_category', columns='second_category', values='actual_price')

sns.heatmap(
    heatmap_data_mean, 
    annot=True, 
    cmap=create_custom_colormap(), 
    fmt='.2f', 
    cbar_kws={'label': 'Actual Price (Mean)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[2]
)
axes[2].set_title('Promedio Actual Price')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Discount percentage

# %%
amazon_unificado['discount_percentage'] = pd.to_numeric(amazon_unificado['discount_percentage'], errors='coerce')

# Asignar la categoría secundaria en base a specific_category
def assign_second_category(specific_category):
    for second_category, categories in category_mapping.items():
        if specific_category in categories:
            return second_category
    return 'Others'  # Para categorías no asignadas

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(assign_second_category)

# Crear la figura con 3 subplots
fig, axes = plt.subplots(3, 1, figsize=(14, 18))

# Definir el mapeo de colores personalizado
def create_custom_colormap():
    colors = ['#FF0000', '#FFFF00', '#00FF00']  # Rojo, Amarillo, Verde
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)
    return cmap

# Función para formatear los valores como porcentaje
def percent_formatter(x):
    return f'{x * 100:.0f}%'

# Calcular el mínimo y graficar
df_pivot_min = amazon_unificado.pivot_table(
    values='discount_percentage', 
    index=['general_category', 'second_category'], 
    aggfunc='min'
).reset_index()
heatmap_data_min = df_pivot_min.pivot(index='general_category', columns='second_category', values='discount_percentage')

sns.heatmap(
    heatmap_data_min, 
    annot=heatmap_data_min.apply(lambda x: x.map(percent_formatter)),  # Aplicar el formateo personalizado
    cmap=create_custom_colormap(), 
    fmt='',  # No formato fijo, ya que usamos `annot`
    cbar_kws={'label': 'Porcentaje de Descuento (Min)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[0]
)
axes[0].set_title('Min Porcentaje de Descuento')

# Calcular el máximo y graficar
df_pivot_max = amazon_unificado.pivot_table(
    values='discount_percentage', 
    index=['general_category', 'second_category'], 
    aggfunc='max'
).reset_index()
heatmap_data_max = df_pivot_max.pivot(index='general_category', columns='second_category', values='discount_percentage')

sns.heatmap(
    heatmap_data_max, 
    annot=heatmap_data_max.apply(lambda x: x.map(percent_formatter)),  # Aplicar el formateo personalizado
    cmap=create_custom_colormap(), 
    fmt='',  # No formato fijo, ya que usamos `annot`
    cbar_kws={'label': 'Porcentaje de Descuento (Max)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[1]
)
axes[1].set_title('Maximo Porcentaje de Descuento')

# Calcular el promedio y graficar
df_pivot_mean = amazon_unificado.pivot_table(
    values='discount_percentage', 
    index=['general_category', 'second_category'], 
    aggfunc='mean'
).reset_index()
heatmap_data_mean = df_pivot_mean.pivot(index='general_category', columns='second_category', values='discount_percentage')

sns.heatmap(
    heatmap_data_mean, 
    annot=heatmap_data_mean.apply(lambda x: x.map(percent_formatter)),  # Aplicar el formateo personalizado
    cmap=create_custom_colormap(), 
    fmt='',  # No formato fijo, ya que usamos `annot`
    cbar_kws={'label': 'Porcentaje de Descuento (Mean)'}, 
    linewidths=0.5,
    annot_kws={"size": 9},
    ax=axes[2]
)
axes[2].set_title('Promedio Porcentaje de Descuento')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Supongamos que amazon_unificado es tu DataFrame

# Función para determinar el tipo de dato de cada columna
def infer_column_types(df):
    types = {}
    for column in df.columns:
        # Obtener los datos únicos de la columna
        unique_values = df[column].dropna().unique()
        
        # Determinar el tipo de dato
        if pd.api.types.is_numeric_dtype(df[column]):
            types[column] = 'Numérico'
        elif pd.api.types.is_string_dtype(df[column]):
            if all(value.replace('.', '', 1).isdigit() for value in unique_values if isinstance(value, str)):
                types[column] = 'Numérico (como texto)'
            else:
                types[column] = 'Texto'
        elif pd.api.types.is_datetime64_any_dtype(df[column]):
            types[column] = 'Fecha/Hora'
        else:
            types[column] = 'Desconocido'
    
    return pd.DataFrame(list(types.items()), columns=['Columna', 'Tipo de Dato'])

# Crear la tabla con el tipo de dato de cada columna
column_types_df = infer_column_types(amazon_unificado)

# Mostrar la tabla
print(column_types_df)
# Out:
#                   Columna           Tipo de Dato
# 0              product_id                  Texto
# 1           reviews_count               Numérico
# 2            review_title                  Texto
# 3          review_content                  Texto
# 4               img_count               Numérico
# 5                img_link                  Texto
# 6            product_link                  Texto
# 7                  rating               Numérico
# 8         category_rating                  Texto
# 9            rating_count               Numérico
# 10  category_rating_count                  Texto
# 11    rating_segmentation                  Texto
# 12           product_name                  Texto
# 13       general_category                  Texto
# 14      specific_category                  Texto
# 15       discounted_price  Numérico (como texto)
# 16           actual_price               Numérico
# 17    discount_percentage               Numérico
# ...

# %% [markdown]
# # Pruebas de significancia

# %% [markdown]
# ## Actual price con categorias.

# %%
import pandas as pd
from scipy import stats

# Define colores en formato HEX
color_normal = '#00BFFF'  # Celeste fuerte para datos normales
color_no_normal = '#D8A8E3'  # Lila claro para datos no normales
color_significant = '#00FF00'  # Verde para diferencias significativas
color_no_significant = '#FF0000'  # Rojo para diferencias no significativas

# Supongamos que `amazon_unificado` es tu DataFrame
categorias_generales = amazon_unificado['general_category'].dropna().unique()
categorias_especificas = amazon_unificado['specific_category'].dropna().unique()

# Generar todas las combinaciones posibles de categorías generales y específicas
categoria_combinaciones = [(categoria_general, categoria_especifica) for categoria_general in categorias_generales for categoria_especifica in categorias_especificas]

# Listas para almacenar resultados
resultados = []

# Para cada combinación de categorías
for categoria_general, categoria_especifica in categoria_combinaciones:
    grupo = amazon_unificado[(amazon_unificado['general_category'] == categoria_general) & 
                             (amazon_unificado['specific_category'] == categoria_especifica)]['actual_price'].dropna()
    
    # Verifica si el grupo tiene datos
    if len(grupo) > 0:
        # Paso 1: Verificar la normalidad
        combined_data = grupo
        
        # Verifica si el tamaño de la muestra es suficiente
        if len(combined_data) < 3:
            distribucion_color = color_no_normal
            prueba_recomendada = 'No aplicable'
            prueba = 'No aplicable'
            resultado_color = color_no_significant
            resultado = 'Tamaño insuficiente'
            p_value = 'No aplicable'
            tipo_distribucion = 'No aplicable'
            porque = 'Tamaño de muestra insuficiente para pruebas estadísticas'
            hipotesis = 'No aplicable'
            resultado_hipotesis = 'No aplicable'
        else:
            try:
                # Prueba de normalidad
                stat_shapiro, p_value_shapiro = stats.shapiro(combined_data)
                tipo_distribucion = 'Normal' if p_value_shapiro > 0.05 else 'No Normal'
                distribucion_color = color_normal if tipo_distribucion == 'Normal' else color_no_normal
                
                if tipo_distribucion == 'Normal':
                    prueba_recomendada = 'Prueba t'
                    # Datos normales, usar prueba t
                    stat, p_value = stats.ttest_1samp(grupo, popmean=combined_data.mean())
                    prueba = 'Prueba t'
                else:
                    prueba_recomendada = 'Mann-Whitney U' if len(grupo) > 1 else 'No aplicable'
                    if len(grupo) > 1:
                        # Datos no normales, usar prueba de Mann-Whitney U
                        stat, p_value = stats.mannwhitneyu(grupo, combined_data)
                        prueba = 'Mann-Whitney U'
                    else:
                        resultado_color = color_no_significant
                        resultado = 'Tamaño insuficiente'
                        p_value = 'No aplicable'
                        porque = 'Tamaño de muestra insuficiente para la prueba Mann-Whitney U'
                        hipotesis = 'No aplicable'
                        resultado_hipotesis = 'No aplicable'
                        resultados.append({
                            'Categoría General': categoria_general,
                            'Categoría Específica': categoria_especifica,
                            'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
                            'Tamaño de Muestra': len(combined_data),
                            'Prueba Recomendada': prueba_recomendada,
                            'Prueba Realizada': prueba,
                            'P-Valor': p_value,
                            'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
                            'Por Qué': porque,
                            'Hipótesis': hipotesis,
                            'Resultado Hipótesis': resultado_hipotesis
                        })
                        continue
                
                # Determinar el resultado
                if p_value < 0.05:
                    resultado_color = color_significant
                    resultado = 'Significativa'
                    resultado_hipotesis = 'Se rechaza'
                else:
                    resultado_color = color_no_significant
                    resultado = 'No significativa'
                    resultado_hipotesis = 'No se rechaza'
                
                porque = 'El valor p indica la significancia de la diferencia entre los grupos'
                hipotesis = 'No hay diferencia significativa en el precio actual (`actual_price`) entre diferentes categorías generales (`general_category`) y específicas (`specific_category`). Las diferencias en los precios se deben al azar y no a la influencia de las categorías.'
                
            except Exception as e:
                distribucion_color = color_no_normal
                prueba = 'Error'
                resultado_color = color_no_significant
                resultado = f'Error: {e}'
                p_value = 'No aplicable'
                tipo_distribucion = 'No aplicable'
                prueba_recomendada = 'No aplicable'
                porque = f'Error durante el cálculo: {e}'
                hipotesis = 'No aplicable'
                resultado_hipotesis = 'No aplicable'
    
    else:
        distribucion_color = 'No aplicable'
        prueba = 'No aplicable'
        resultado_color = color_no_significant
        resultado = 'Datos insuficientes'
        p_value = 'No aplicable'
        tipo_distribucion = 'No aplicable'
        prueba_recomendada = 'No aplicable'
        porque = 'Datos insuficientes para realizar la prueba'
        hipotesis = 'No aplicable'
        resultado_hipotesis = 'No aplicable'

    # Almacena resultados
    resultados.append({
        'Categoría General': categoria_general,
        'Categoría Específica': categoria_especifica,
        'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
        'Tamaño de Muestra': len(combined_data),
        'Prueba Recomendada': prueba_recomendada,
        'Prueba Realizada': prueba,
        'P-Valor': p_value,
        'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
        'Por Qué': porque,
        'Hipótesis': hipotesis,
        'Resultado Hipótesis': resultado_hipotesis
    })

# Convertir resultados en DataFrame
df_resultados = pd.DataFrame(resultados)

# Exportar a HTML
html_content = df_resultados.to_html(escape=False, index=False)

# Crear archivo HTML
with open('significancia.html', 'w') as file:
    file.write(f"""
    <!DOCTYPE html>
    <html>
    <head>
        <style>
            body {{
                background-color: #2e2e2e;
                color: #ffffff;
                font-family: Arial, sans-serif;
            }}
            table {{
                width: 100%;
                border-collapse: collapse;
            }}
            th, td {{
                border: 1px solid #dddddd;
                text-align: left;
                padding: 8px;
            }}
            th {{
                background-color: #444444;
            }}
            tr:nth-child(even) {{
                background-color: #333333;
            }}
            tr:nth-child(odd) {{
                background-color: #2e2e2e;
            }}
        </style>
    </head>
    <body>
        <h1>Resultados de Significancia</h1>
        {html_content}
    </body>
    </html>
    """)

# %%
import pandas as pd
from scipy import stats

# Define colores en formato HEX
color_normal = '#00BFFF'  # Celeste fuerte para datos normales
color_no_normal = '#D8A8E3'  # Lila claro para datos no normales
color_significant = '#00FF00'  # Verde para diferencias significativas
color_no_significant = '#FF0000'  # Rojo para diferencias no significativas

# Mapeo de categorías
category_mapping = {
    'Electronics': [
        'USBCables', 'RemoteControls', 'In-Ear', 'SmartWatches', 'SmartTelevisions', 
        'Smartphones', 'Mice', 'HDMICables', 'WallChargers', 'ScreenProtectors', 
        'GraphicTablets', 'WirelessUSBAdapters', 'PenDrives', 'Routers', 
        'ExternalHardDisks', 'BluetoothSpeakers', 'TVWall&CeilingMounts', 
        'Lamps', 'Headsets', 'Projectors', 'Webcams', 'Monitors', 'PCSpeakers',
        'VideoCameras', 'PowerBanks', 'AVReceivers&Amplifiers', 'SelfieSticks', 
        'Printers', 'SatelliteReceivers', 'Humidifiers', 'Condenser', 'ExternalMemoryCardReaders', 
        'EthernetCables', 'CameraPrivacyCovers', 'DigitalScales', 'Scientific', 
        'PCMicrophones', 'USBtoUSBAdapters', 'Over-Ear', 'OTGAdapters'
    ],
    'Kitchen Appliances': [
        'MixerGrinders', 'DryIrons', 'InstantWaterHeaters', 'LintShavers', 
        'ElectricHeaters', 'ElectricKettles', 'FanHeaters', 'HandBlenders', 
        'JuicerMixerGrinders', 'SteamIrons', 'SandwichMakers', 'EggBoilers', 
        'InductionCooktop', 'ImmersionRods', 'DigitalKitchenScales', 'AirFryers', 
        'DripCoffeeMachines', 'Pop-upToasters', 'MilkFrothers', 'ColdPressJuicers', 
        'HandMixers', 'WaffleMakers&Irons', 'OvenToasterGrills', 'Rice&PastaCookers', 
        'EspressoMachines', 'ElectricGrinders', 'RotiMakers', 'StovetopEspressoPots', 
        'YogurtMakers', 'Juicers', 'SteamIrons', 'ElectricHeaters'
    ],
    'Home Appliances': [
        'CeilingFans', 'WaterFilters&Purifiers', 'StorageWaterHeaters', 
        'WaterPurifierAccessories', 'ExhaustFans', 'PressureWashers,Steam&WindowCleaners', 
        'RoboticVacuums', 'WetGrinders', 'RoomHeaters', 'HalogenHeaters', 'HeatConvectors', 
        'AirPurifiers&Ionizers', 'FanParts&Accessories', 'TableFans', 'PedestalFans', 
        'SmallKitchenAppliances', 'StandMixers', 'SteamIrons'
    ],
    'Computing Accessories': [
        'Lapdesks', 'Keyboard&MouseSets', 'Laptops', 'MousePads', 
        'Notebooks,WritingPads&Diaries', 'USBHubs', 'Tablets', 'SurgeProtectors',
        'NetworkingDevices', 'CoolingPads', 'LaptopChargers&PowerSupplies', 
        'InternalHardDrives', 'InkjetPrinters', 'SATA Cables', 'Cable Connection Protectors'
    ],
    'Office Supplies': [
        'CompositionNotebooks', 'DisposableBatteries', 'Notepads&MemoBooks', 
        'CompleteTripodUnits', 'WoodenPencils', 'StickBallpointPens', 
        'GelInkRollerballPens', 'SprayBottles', 'DomeCameras', 'DustCovers', 
        'ExternalSolidStateDrives', 'InternalSolidStateDrives', 'BottledInk',
        'Financial&Business', 'BasicCases', 'Scientific'
    ],
    'Gaming': [
        'Gamepads', 'GamingMice', 'GamingKeyboards', 'Routers', 
        'ExternalHardDisks', 'Printers', 'Projectors', 'StylusPens', 'Notepads'
    ],
    'Audio Accessories': [
        'BluetoothSpeakers', 'StylusPens', 'AirFryers', 'OTGAdapters', 
        'CanisterVacuums', 'MultimediaSpeakerSystems', 'Pop-upToasters'
    ],
    'Wearable Technology': [
        'SmartWatches', 'Headsets', 'In-Ear', 'Over-Ear', 
        'BasicMobiles', 'SelfieLights', 'BluetoothSpeakers', 'EthernetCables', 
        'Tripods', 'Macro&RinglightFlashes', 'Cradles', 'PhoneCharms'
    ],
    'Power Supplies': [
        'BatteryChargers', 'PowerLANAdapters', 'Adapters', 'SurgeProtectors',
        'Charging Stations', 'PowerBanks', 'Adapters&Multi-Outlets', 'UninterruptedPowerSupplies'
    ],
    'Data Storage': [
        'Memory', 'ExternalSolidStateDrives', 'ExternalHardDisks', 
        'USBHubs', 'PenDrives', 'InternalSolidStateDrives', 'MemoryCards'
    ],
    'Kitchenware': [
        'Juicers', 'DripCoffeeMachines', 'CoffeePresses', 'MilkFrothers', 
        'ColdPressJuicers', 'Caddies', 'MixerGrinders', 'LintShavers', 
        'HandheldVacuums', 'Sewing&EmbroideryMachines', 'Kitchen Storage'
    ],
    'Health & Personal Care': [
        'HandheldVacuums', 'ElectricKettles', 'MilkFrothers', 'AirPurifiers&Ionizers', 
        'PowerLANAdapters', 'TableFans', 'VacuumSealers', 'RoomHeaters', 
        'PersonalCareAppliances', 'MeasuringSpoons', 'MassageDevices'
    ],
    'Cleaning Appliances': [
        'HandheldVacuums', 'RoboticVacuums', 'CanisterVacuums', 'Wet-DryVacuums', 
        'SteamCleaners', 'PressureWashers', 'WindowCleaners', 'ImmersionRods'
    ],
    'Security & Surveillance': [
        'DomeCameras', 'WirelessSecurityCameras', 'SelfieSticks', 'CameraPrivacyCovers', 
        'Macro&RinglightFlashes', 'SurveillanceSystems', 'SecurityAlarms'
    ],
    'Networking': [
        'PowerLANAdapters', 'Routers', 'NetworkingDevices', 'USBAdapters', 
        'Repeaters&Extenders', 'AVReceivers&Amplifiers', 'ChargingStations'
    ],
    'Pet Supplies': [
        'AutomaticFeeders', 'PetBowls', 'PetGrooming', 'PetLeashes', 
        'PetCarriers', 'PetBeds', 'PetToilets', 'PetCleaning'
    ],
    'Stationery & Art Supplies': [
        'ColouredPaper', 'ColouringPens&Markers', 'Staplers', 'StickyNotes', 
        'Highlighters', 'Paints', 'Notebooks', 'SketchPads'
    ],
    'Fashion Accessories': [
        'StylusPens', 'Sewing&EmbroideryMachines', 'HandheldBags', 'Bags', 
        'Wallets', 'TravelAccessories', 'Belts', 'Watches'
    ],
    'Automotive': [
        'CarAccessories', 'MotorcycleAccessories', 'CarInteriorAccessories', 
        'AutomobileChargers', 'BatteryChargers', 'CarCleaningKits', 'MotorcycleHelmets'
    ],
    'Baby Products': [
        'BabyMonitors', 'Cribs', 'Playpens', 'BabyCarriers', 
        'Strollers', 'BabyBottles', 'BabyCarriers', 'ChangingMats'
    ],
    'Home Décor': [
        'Cushions&Throws', 'WallArt', 'Lighting', 'Mirrors', 
        'TableLamps', 'PictureFrames', 'WallClocks', 'Vases'
    ],
    'Jewellery': [
        'Necklaces', 'Earrings', 'Bracelets', 'Watches', 
        'Rings', 'JewelleryBoxes', 'JewelleryCleaningKits', 'JewelleryRepairKits'
    ],
    'Sports & Fitness': [
        'ExerciseEquipment', 'CampingGear', 'SportsShoes', 
        'FitnessTech', 'OutdoorGames', 'Cycling', 'Skiing&Snowboarding'
    ],
    'Tools': [
        'PowerTools', 'HandTools', 'MeasuringTools', 'WorkshopTools', 
        'ToolStorage', 'WeldingTools', 'ToolKits', 'GardenTools'
    ],
    'Beauty Products': [
        'Skincare', 'Make-up', 'Haircare', 'Perfumes', 
        'OralCare', 'NailCare', 'HairColoring', 'Men’sGrooming'
    ],
    'Home Improvement': [
        'Lighting', 'DoorHardware&Locks', 'BathroomHardware', 
        'Paint', 'Electrical', 'Flooring', 'OutdoorFurniture'
    ]
}

# Crear la columna 'second_category'
def get_second_category(category):
    for general_category, specific_categories in category_mapping.items():
        if category in specific_categories:
            return general_category
    return None

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(get_second_category)

# Obtén las combinaciones únicas de general_category y second_category
categorias_generales = amazon_unificado['general_category'].dropna().unique()
categorias_secundarias = amazon_unificado['second_category'].dropna().unique()

# Generar todas las combinaciones posibles de categorías generales y secundarias
categoria_combinaciones = [(categoria_general, categoria_secundaria) for categoria_general in categorias_generales for categoria_secundaria in categorias_secundarias]

# Listas para almacenar resultados
resultados = []

# Para cada combinación de categorías
for categoria_general, categoria_secundaria in categoria_combinaciones:
    grupo = amazon_unificado[(amazon_unificado['general_category'] == categoria_general) & 
                             (amazon_unificado['second_category'] == categoria_secundaria)]['actual_price'].dropna()
    
    # Verifica si el grupo tiene datos
    if len(grupo) > 0:
        # Paso 1: Verificar la normalidad
        combined_data = grupo
        
        # Verifica si el tamaño de la muestra es suficiente
        if len(combined_data) < 3:
            distribucion_color = color_no_normal
            prueba_recomendada = 'No aplicable'
            prueba = 'No aplicable'
            resultado_color = color_no_significant
            resultado = 'Tamaño insuficiente'
            p_value = 'No aplicable'
            tipo_distribucion = 'No aplicable'
            porque = 'Tamaño de muestra insuficiente para pruebas estadísticas'
            hipotesis = 'No aplicable'
            resultado_hipotesis = 'No aplicable'
        else:
            try:
                # Prueba de normalidad
                stat_shapiro, p_value_shapiro = stats.shapiro(combined_data)
                tipo_distribucion = 'Normal' if p_value_shapiro > 0.05 else 'No Normal'
                distribucion_color = color_normal if tipo_distribucion == 'Normal' else color_no_normal
                
                if tipo_distribucion == 'Normal':
                    prueba_recomendada = 'Prueba t'
                    # Datos normales, usar prueba t
                    stat, p_value = stats.ttest_1samp(grupo, popmean=combined_data.mean())
                    prueba = 'Prueba t'
                else:
                    prueba_recomendada = 'Mann-Whitney U' if len(grupo) > 1 else 'No aplicable'
                    if len(grupo) > 1:
                        # Datos no normales, usar prueba de Mann-Whitney U
                        stat, p_value = stats.mannwhitneyu(grupo, combined_data)
                        prueba = 'Mann-Whitney U'
                    else:
                        resultado_color = color_no_significant
                        resultado = 'Tamaño insuficiente'
                        p_value = 'No aplicable'
                        porque = 'Tamaño de muestra insuficiente para la prueba Mann-Whitney U'
                        hipotesis = 'No aplicable'
                        resultado_hipotesis = 'No aplicable'
                        resultados.append({
                            'Categoría General': categoria_general,
                            'Segunda Categoría': categoria_secundaria,
                            'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
                            'Tamaño de Muestra': len(combined_data),
                            'Prueba Recomendada': prueba_recomendada,
                            'Prueba Realizada': prueba,
                            'P-Valor': p_value,
                            'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
                            'Por Qué': porque,
                            'Hipótesis': hipotesis,
                            'Resultado Hipótesis': resultado_hipotesis
                        })
                        continue
                
                # Determinar el resultado
                if p_value < 0.05:
                    resultado_color = color_significant
                    resultado = 'Significativa'
                    resultado_hipotesis = 'Se rechaza'
                else:
                    resultado_color = color_no_significant
                    resultado = 'No significativa'
                    resultado_hipotesis = 'No se rechaza'
                
                porque = 'El valor p indica la significancia de la diferencia entre los grupos'
                hipotesis = 'No hay diferencia significativa en el precio actual (`actual_price`) entre diferentes categorías generales (`general_category`) y secundarias (`second_category`). Las diferencias en los precios se deben al azar y no a la influencia de las categorías.'
                
            except Exception as e:
                distribucion_color = color_no_normal
                prueba = 'Error'
                resultado_color = color_no_significant
                resultado = f'Error: {e}'
                p_value = 'No aplicable'
                tipo_distribucion = 'No aplicable'
                prueba_recomendada = 'No aplicable'
                porque = f'Error durante el cálculo: {e}'
                hipotesis = 'No aplicable'
                resultado_hipotesis = 'No aplicable'
    
    else:
        distribucion_color = 'No aplicable'
        prueba = 'No aplicable'
        resultado_color = color_no_significant
        resultado = 'Datos insuficientes'
        p_value = 'No aplicable'
        tipo_distribucion = 'No aplicable'
        prueba_recomendada = 'No aplicable'
        porque = 'Datos insuficientes para realizar la prueba'
        hipotesis = 'No aplicable'
        resultado_hipotesis = 'No aplicable'

    # Almacena resultados
    resultados.append({
        'Categoría General': categoria_general,
        'Segunda Categoría': categoria_secundaria,
        'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
        'Tamaño de Muestra': len(combined_data),
        'Prueba Recomendada': prueba_recomendada,
        'Prueba Realizada': prueba,
        'P-Valor': p_value,
        'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
        'Por Qué': porque,
        'Hipótesis': hipotesis,
        'Resultado Hipótesis': resultado_hipotesis
    })

# Convertir resultados en DataFrame
df_resultados = pd.DataFrame(resultados)

# Exportar a HTML
html_content = df_resultados.to_html(escape=False, index=False)

# Crear archivo HTML
with open('second_significancia.html', 'w') as file:
    file.write(f"""
    <!DOCTYPE html>
    <html>
    <head>
        <style>
            body {{
                background-color: #2e2e2e;
                color: #ffffff;
                font-family: Arial, sans-serif;
            }}
            table {{
                width: 100%;
                border-collapse: collapse;
            }}
            th, td {{
                border: 1px solid #dddddd;
                text-align: left;
                padding: 8px;
            }}
            th {{
                background-color: #444444;
            }}
            tr:nth-child(even) {{
                background-color: #333333;
            }}
            tr:nth-child(odd) {{
                background-color: #222222;
            }}
        </style>
    </head>
    <body>
        <h2>Resultados de Pruebas Estadísticas</h2>
        {html_content}
    </body>
    </html>
    """)

# %% [markdown]
# ## discount percentage

# %% [markdown]
# ### Kruskal-Wallis H

# %%
import pandas as pd
from scipy import stats

# Define colores en formato HEX
color_normal = '#00BFFF'  # Celeste fuerte para datos normales
color_no_normal = '#D8A8E3'  # Lila claro para datos no normales
color_significant = '#00FF00'  # Verde para diferencias significativas
color_no_significant = '#FF0000'  # Rojo para diferencias no significativas

# Supongamos que `amazon_unificado` es tu DataFrame
categorias_generales = amazon_unificado['general_category'].dropna().unique()

# Listas para almacenar resultados
resultados = []

# Para cada categoría general
for categoria_general in categorias_generales:
    grupo = amazon_unificado[amazon_unificado['general_category'] == categoria_general]['discount_percentage'].dropna()
    
    # Verifica si el grupo tiene datos
    if len(grupo) > 0:
        # Paso 1: Verificar la normalidad
        combined_data = amazon_unificado['discount_percentage'].dropna()
        
        # Verifica si el tamaño de la muestra es suficiente
        if len(combined_data) < 3:
            distribucion_color = color_no_normal
            prueba_recomendada = 'No aplicable'
            prueba = 'No aplicable'
            resultado_color = color_no_significant
            resultado = 'Tamaño insuficiente'
            p_value = 'No aplicable'
            tipo_distribucion = 'No aplicable'
            porque = 'Tamaño de muestra insuficiente para pruebas estadísticas'
            hipotesis = 'No aplicable'
            resultado_hipotesis = 'No aplicable'
        else:
            try:
                # Prueba de normalidad
                stat_shapiro, p_value_shapiro = stats.shapiro(combined_data)
                tipo_distribucion = 'Normal' if p_value_shapiro > 0.05 else 'No Normal'
                distribucion_color = color_normal if tipo_distribucion == 'Normal' else color_no_normal
                
                if tipo_distribucion == 'Normal':
                    prueba_recomendada = 'ANOVA'
                    # Datos normales, usar ANOVA
                    grupos = [amazon_unificado[amazon_unificado['general_category'] == cat]['discount_percentage'].dropna() for cat in categorias_generales]
                    stat, p_value = stats.f_oneway(*grupos)
                    prueba = 'ANOVA'
                else:
                    prueba_recomendada = 'Kruskal-Wallis H'
                    # Datos no normales, usar prueba de Kruskal-Wallis
                    grupos = [amazon_unificado[amazon_unificado['general_category'] == cat]['discount_percentage'].dropna() for cat in categorias_generales]
                    stat, p_value = stats.kruskal(*grupos)
                    prueba = 'Kruskal-Wallis H'
                
                # Determinar el resultado
                if p_value < 0.05:
                    resultado_color = color_significant
                    resultado = 'Significativa'
                    resultado_hipotesis = 'Se rechaza'
                else:
                    resultado_color = color_no_significant
                    resultado = 'No significativa'
                    resultado_hipotesis = 'No se rechaza'
                
                porque = 'El valor p indica la significancia de la diferencia en el descuento (`discount_percentage`) entre diferentes categorías generales (`general_category`).'
                hipotesis = 'No hay diferencia significativa en el porcentaje de descuento (`discount_percentage`) entre diferentes categorías generales (`general_category`). Las diferencias en los descuentos se deben al azar y no a la influencia de las categorías.'
                
            except Exception as e:
                distribucion_color = color_no_normal
                prueba = 'Error'
                resultado_color = color_no_significant
                resultado = f'Error: {e}'
                p_value = 'No aplicable'
                tipo_distribucion = 'No aplicable'
                prueba_recomendada = 'No aplicable'
                porque = f'Error durante el cálculo: {e}'
                hipotesis = 'No aplicable'
                resultado_hipotesis = 'No aplicable'
    
    else:
        distribucion_color = 'No aplicable'
        prueba = 'No aplicable'
        resultado_color = color_no_significant
        resultado = 'Datos insuficientes'
        p_value = 'No aplicable'
        tipo_distribucion = 'No aplicable'
        prueba_recomendada = 'No aplicable'
        porque = 'Datos insuficientes para realizar la prueba'
        hipotesis = 'No aplicable'
        resultado_hipotesis = 'No aplicable'

    # Almacena resultados
    resultados.append({
        'Categoría General': categoria_general,
        'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
        'Tamaño de Muestra': len(grupo),
        'Prueba Recomendada': prueba_recomendada,
        'Prueba Realizada': prueba,
        'P-Valor': p_value,
        'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
        'Por Qué': porque,
        'Hipótesis': hipotesis,
        'Resultado Hipótesis': resultado_hipotesis
    })

# Convertir resultados en DataFrame
df_resultados = pd.DataFrame(resultados)

# Exportar a HTML
html_content = df_resultados.to_html(escape=False, index=False)

# Crear archivo HTML
with open('significancia_discount_percentage.html', 'w') as file:
    file.write(f"""
    <!DOCTYPE html>
    <html>
    <head>
        <style>
            body {{
                background-color: #2e2e2e;
                color: #ffffff;
                font-family: Arial, sans-serif;
            }}
            table {{
                width: 100%;
                border-collapse: collapse;
            }}
            th, td {{
                border: 1px solid #dddddd;
                text-align: left;
                padding: 8px;
            }}
            th {{
                background-color: #444444;
            }}
            tr:nth-child(even) {{
                background-color: #333333;
            }}
            tr:nth-child(odd) {{
                background-color: #2e2e2e;
            }}
        </style>
    </head>
    <body>
        <h1>Resultados de Significancia para Discount Percentage</h1>
        {html_content}
    </body>
    </html>
    """)

# %%
import pandas as pd
from scipy import stats

# Define colores en formato HEX
color_normal = '#00BFFF'  # Celeste fuerte para datos normales
color_no_normal = '#D8A8E3'  # Lila claro para datos no normales
color_significant = '#00FF00'  # Verde para diferencias significativas
color_no_significant = '#FF0000'  # Rojo para diferencias no significativas


# Mapeo de categorías
category_mapping = {
    'Electronics': [
        'USBCables', 'RemoteControls', 'In-Ear', 'SmartWatches', 'SmartTelevisions', 
        'Smartphones', 'Mice', 'HDMICables', 'WallChargers', 'ScreenProtectors', 
        'GraphicTablets', 'WirelessUSBAdapters', 'PenDrives', 'Routers', 
        'ExternalHardDisks', 'BluetoothSpeakers', 'TVWall&CeilingMounts', 
        'Lamps', 'Headsets', 'Projectors', 'Webcams', 'Monitors', 'PCSpeakers',
        'VideoCameras', 'PowerBanks', 'AVReceivers&Amplifiers', 'SelfieSticks', 
        'Printers', 'SatelliteReceivers', 'Humidifiers', 'Condenser', 'ExternalMemoryCardReaders', 
        'EthernetCables', 'CameraPrivacyCovers', 'DigitalScales', 'Scientific', 
        'PCMicrophones', 'USBtoUSBAdapters', 'Over-Ear', 'OTGAdapters'
    ],
    'Kitchen Appliances': [
        'MixerGrinders', 'DryIrons', 'InstantWaterHeaters', 'LintShavers', 
        'ElectricHeaters', 'ElectricKettles', 'FanHeaters', 'HandBlenders', 
        'JuicerMixerGrinders', 'SteamIrons', 'SandwichMakers', 'EggBoilers', 
        'InductionCooktop', 'ImmersionRods', 'DigitalKitchenScales', 'AirFryers', 
        'DripCoffeeMachines', 'Pop-upToasters', 'MilkFrothers', 'ColdPressJuicers', 
        'HandMixers', 'WaffleMakers&Irons', 'OvenToasterGrills', 'Rice&PastaCookers', 
        'EspressoMachines', 'ElectricGrinders', 'RotiMakers', 'StovetopEspressoPots', 
        'YogurtMakers', 'Juicers', 'SteamIrons', 'ElectricHeaters'
    ],
    'Home Appliances': [
        'CeilingFans', 'WaterFilters&Purifiers', 'StorageWaterHeaters', 
        'WaterPurifierAccessories', 'ExhaustFans', 'PressureWashers,Steam&WindowCleaners', 
        'RoboticVacuums', 'WetGrinders', 'RoomHeaters', 'HalogenHeaters', 'HeatConvectors', 
        'AirPurifiers&Ionizers', 'FanParts&Accessories', 'TableFans', 'PedestalFans', 
        'SmallKitchenAppliances', 'StandMixers', 'SteamIrons'
    ],
    'Computing Accessories': [
        'Lapdesks', 'Keyboard&MouseSets', 'Laptops', 'MousePads', 
        'Notebooks,WritingPads&Diaries', 'USBHubs', 'Tablets', 'SurgeProtectors',
        'NetworkingDevices', 'CoolingPads', 'LaptopChargers&PowerSupplies', 
        'InternalHardDrives', 'InkjetPrinters', 'SATA Cables', 'Cable Connection Protectors'
    ],
    'Office Supplies': [
        'CompositionNotebooks', 'DisposableBatteries', 'Notepads&MemoBooks', 
        'CompleteTripodUnits', 'WoodenPencils', 'StickBallpointPens', 
        'GelInkRollerballPens', 'SprayBottles', 'DomeCameras', 'DustCovers', 
        'ExternalSolidStateDrives', 'InternalSolidStateDrives', 'BottledInk',
        'Financial&Business', 'BasicCases', 'Scientific'
    ],
    'Gaming': [
        'Gamepads', 'GamingMice', 'GamingKeyboards', 'Routers', 
        'ExternalHardDisks', 'Printers', 'Projectors', 'StylusPens', 'Notepads'
    ],
    'Audio Accessories': [
        'BluetoothSpeakers', 'StylusPens', 'AirFryers', 'OTGAdapters', 
        'CanisterVacuums', 'MultimediaSpeakerSystems', 'Pop-upToasters'
    ],
    'Wearable Technology': [
        'SmartWatches', 'Headsets', 'In-Ear', 'Over-Ear', 
        'BasicMobiles', 'SelfieLights', 'BluetoothSpeakers', 'EthernetCables', 
        'Tripods', 'Macro&RinglightFlashes', 'Cradles', 'PhoneCharms'
    ],
    'Power Supplies': [
        'BatteryChargers', 'PowerLANAdapters', 'Adapters', 'SurgeProtectors',
        'Charging Stations', 'PowerBanks', 'Adapters&Multi-Outlets', 'UninterruptedPowerSupplies'
    ],
    'Data Storage': [
        'Memory', 'ExternalSolidStateDrives', 'ExternalHardDisks', 
        'USBHubs', 'PenDrives', 'InternalSolidStateDrives', 'MemoryCards'
    ],
    'Kitchenware': [
        'Juicers', 'DripCoffeeMachines', 'CoffeePresses', 'MilkFrothers', 
        'ColdPressJuicers', 'Caddies', 'MixerGrinders', 'LintShavers', 
        'HandheldVacuums', 'Sewing&EmbroideryMachines', 'Kitchen Storage'
    ],
    'Health & Personal Care': [
        'HandheldVacuums', 'ElectricKettles', 'MilkFrothers', 'AirPurifiers&Ionizers', 
        'PowerLANAdapters', 'TableFans', 'VacuumSealers', 'RoomHeaters', 
        'PersonalCareAppliances', 'MeasuringSpoons', 'MassageDevices'
    ],
    'Cleaning Appliances': [
        'HandheldVacuums', 'RoboticVacuums', 'CanisterVacuums', 'Wet-DryVacuums', 
        'SteamCleaners', 'PressureWashers', 'WindowCleaners', 'ImmersionRods'
    ],
    'Security & Surveillance': [
        'DomeCameras', 'WirelessSecurityCameras', 'SelfieSticks', 'CameraPrivacyCovers', 
        'Macro&RinglightFlashes', 'SurveillanceSystems', 'SecurityAlarms'
    ],
    'Networking': [
        'PowerLANAdapters', 'Routers', 'NetworkingDevices', 'USBAdapters', 
        'Repeaters&Extenders', 'AVReceivers&Amplifiers', 'ChargingStations'
    ],
    'Pet Supplies': [
        'AutomaticFeeders', 'PetBowls', 'PetGrooming', 'PetLeashes', 
        'PetCarriers', 'PetBeds', 'PetToilets', 'PetCleaning'
    ],
    'Stationery & Art Supplies': [
        'ColouredPaper', 'ColouringPens&Markers', 'Staplers', 'StickyNotes', 
        'Highlighters', 'Paints', 'Notebooks', 'SketchPads'
    ],
    'Fashion Accessories': [
        'StylusPens', 'Sewing&EmbroideryMachines', 'HandheldBags', 'Bags', 
        'Wallets', 'TravelAccessories', 'Belts', 'Watches'
    ],
    'Automotive': [
        'CarAccessories', 'MotorcycleAccessories', 'CarInteriorAccessories', 
        'AutomobileChargers', 'BatteryChargers', 'CarCleaningKits', 'MotorcycleHelmets'
    ],
    'Baby Products': [
        'BabyMonitors', 'Cribs', 'Playpens', 'BabyCarriers', 
        'Strollers', 'BabyBottles', 'BabyCarriers', 'ChangingMats'
    ],
    'Home Décor': [
        'Cushions&Throws', 'WallArt', 'Lighting', 'Mirrors', 
        'TableLamps', 'PictureFrames', 'WallClocks', 'Vases'
    ],
    'Jewellery': [
        'Necklaces', 'Earrings', 'Bracelets', 'Watches', 
        'Rings', 'JewelleryBoxes', 'JewelleryCleaningKits', 'JewelleryRepairKits'
    ],
    'Sports & Fitness': [
        'ExerciseEquipment', 'CampingGear', 'SportsShoes', 
        'FitnessTech', 'OutdoorGames', 'Cycling', 'Skiing&Snowboarding'
    ],
    'Tools': [
        'PowerTools', 'HandTools', 'MeasuringTools', 'WorkshopTools', 
        'ToolStorage', 'WeldingTools', 'ToolKits', 'GardenTools'
    ],
    'Beauty Products': [
        'Skincare', 'Make-up', 'Haircare', 'Perfumes', 
        'OralCare', 'NailCare', 'HairColoring', 'Men’sGrooming'
    ],
    'Home Improvement': [
        'Lighting', 'DoorHardware&Locks', 'BathroomHardware', 
        'Paint', 'Electrical', 'Flooring', 'OutdoorFurniture'
    ]
}

# Crear la columna 'second_category'
def get_second_category(category):
    for general_category, specific_categories in category_mapping.items():
        if category in specific_categories:
            return general_category
    return None

amazon_unificado['second_category'] = amazon_unificado['specific_category'].apply(get_second_category)

# Obtén las combinaciones únicas de general_category y second_category
categorias_generales = amazon_unificado['general_category'].dropna().unique()
categorias_secundarias = amazon_unificado['second_category'].dropna().unique()

# Generar todas las combinaciones posibles de categorías generales y secundarias
categoria_combinaciones = [(categoria_general, categoria_secundaria) for categoria_general in categorias_generales for categoria_secundaria in categorias_secundarias]

# Listas para almacenar resultados
resultados = []

# Para cada combinación de categorías
for categoria_general, categoria_secundaria in categoria_combinaciones:
    grupo = amazon_unificado[(amazon_unificado['general_category'] == categoria_general) & 
                             (amazon_unificado['second_category'] == categoria_secundaria)]['discount_percentage'].dropna()
    
    # Verifica si el grupo tiene datos
    if len(grupo) > 0:
        # Paso 1: Verificar la normalidad
        combined_data = grupo
        
        # Verifica si el tamaño de la muestra es suficiente
        if len(combined_data) < 3:
            distribucion_color = color_no_normal
            prueba_recomendada = 'No aplicable'
            prueba = 'No aplicable'
            resultado_color = color_no_significant
            resultado = 'Tamaño insuficiente'
            p_value = 'No aplicable'
            tipo_distribucion = 'No aplicable'
            porque = 'Tamaño de muestra insuficiente para pruebas estadísticas'
            hipotesis = 'No aplicable'
            resultado_hipotesis = 'No aplicable'
        else:
            try:
                # Prueba de normalidad
                stat_shapiro, p_value_shapiro = stats.shapiro(combined_data)
                tipo_distribucion = 'Normal' if p_value_shapiro > 0.05 else 'No Normal'
                distribucion_color = color_normal if tipo_distribucion == 'Normal' else color_no_normal
                
                if tipo_distribucion == 'Normal':
                    prueba_recomendada = 'Prueba t'
                    # Datos normales, usar prueba t
                    stat, p_value = stats.ttest_1samp(grupo, popmean=combined_data.mean())
                    prueba = 'Prueba t'
                else:
                    prueba_recomendada = 'Mann-Whitney U' if len(grupo) > 1 else 'No aplicable'
                    if len(grupo) > 1:
                        # Datos no normales, usar prueba de Mann-Whitney U
                        stat, p_value = stats.mannwhitneyu(grupo, combined_data)
                        prueba = 'Mann-Whitney U'
                    else:
                        resultado_color = color_no_significant
                        resultado = 'Tamaño insuficiente'
                        p_value = 'No aplicable'
                        porque = 'Tamaño de muestra insuficiente para la prueba Mann-Whitney U'
                        hipotesis = 'No aplicable'
                        resultado_hipotesis = 'No aplicable'
                        resultados.append({
                            'Categoría General': categoria_general,
                            'Segunda Categoría': categoria_secundaria,
                            'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
                            'Tamaño de Muestra': len(combined_data),
                            'Prueba Recomendada': prueba_recomendada,
                            'Prueba Realizada': prueba,
                            'P-Valor': p_value,
                            'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
                            'Por Qué': porque,
                            'Hipótesis': hipotesis,
                            'Resultado Hipótesis': resultado_hipotesis
                        })
                        continue
                
                # Determinar el resultado
                if p_value < 0.05:
                    resultado_color = color_significant
                    resultado = 'Significativa'
                    resultado_hipotesis = 'Se rechaza'
                else:
                    resultado_color = color_no_significant
                    resultado = 'No significativa'
                    resultado_hipotesis = 'No se rechaza'
                
                porque = 'El valor p indica la significancia de la diferencia entre los grupos'
                hipotesis = 'No hay diferencia significativa en el porcentaje de descuento (`discount_percentage`) entre diferentes categorías generales (`general_category`) y secundarias (`second_category`). Las diferencias en los descuentos se deben al azar y no a la influencia de las categorías.'
                
            except Exception as e:
                distribucion_color = color_no_normal
                prueba = 'Error'
                resultado_color = color_no_significant
                resultado = f'Error: {e}'
                p_value = 'No aplicable'
                tipo_distribucion = 'No aplicable'
                prueba_recomendada = 'No aplicable'
                porque = f'Error durante el cálculo: {e}'
                hipotesis = 'No aplicable'
                resultado_hipotesis = 'No aplicable'
    
    else:
        distribucion_color = 'No aplicable'
        prueba = 'No aplicable'
        resultado_color = color_no_significant
        resultado = 'Datos insuficientes'
        p_value = 'No aplicable'
        tipo_distribucion = 'No aplicable'
        prueba_recomendada = 'No aplicable'
        porque = 'Datos insuficientes para realizar la prueba'
        hipotesis = 'No aplicable'
        resultado_hipotesis = 'No aplicable'

    # Almacena resultados
    resultados.append({
        'Categoría General': categoria_general,
        'Segunda Categoría': categoria_secundaria,
        'Distribución Normal': f'<span style="color:{distribucion_color}">{tipo_distribucion}</span>',
        'Tamaño de Muestra': len(combined_data),
        'Prueba Recomendada': prueba_recomendada,
        'Prueba Realizada': prueba,
        'P-Valor': p_value,
        'Resultado': f'<span style="color:{resultado_color}">{resultado}</span>',
        'Por Qué': porque,
        'Hipótesis': hipotesis,
        'Resultado Hipótesis': resultado_hipotesis
    })

# Convertir resultados en DataFrame
df_resultados = pd.DataFrame(resultados)

# Exportar a HTML
html_content = df_resultados.to_html(escape=False, index=False)

# Crear archivo HTML
with open('second_percentage_significancia.html', 'w') as file:
    file.write(f"""
    <!DOCTYPE html>
    <html>
    <head>
        <style>
            body {{
                background-color: #2e2e2e;
                color: #ffffff;
                font-family: Arial, sans-serif;
            }}
            table {{
                width: 100%;
                border-collapse: collapse;
            }}
            th, td {{
                border: 1px solid #dddddd;
                text-align: left;
                padding: 8px;
            }}
            th {{
                background-color: #444444;
            }}
            tr:nth-child(even) {{
                background-color: #333333;
            }}
            tr:nth-child(odd) {{
                background-color: #222222;
            }}
        </style>
    </head>
    <body>
        <h2>Resultados de Pruebas Estadísticas</h2>
        {html_content}
    </body>
    </html>
    """)

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display

# Cargar el DataFrame df_unificado
df_unificado = amazon_unificado

# Definir las combinaciones específicas
specific_combinations = [
    ('Electronics', 'RemoteControls'),
    ('Computers&Accessories', 'USBCables'),
]

# Resultado esperado como DataFrame
results = []

# Iterar sobre las combinaciones específicas
for general_cat, specific_cat in specific_combinations:
    # Filtrar datos por categoría general y específica
    specific_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] == specific_cat)
    ]
    
    # Convertir a valores numéricos, ignorando errores y eliminando NaN
    actual_prices = pd.to_numeric(specific_subset['actual_price'], errors='coerce').dropna()
    
    # Verificar si hay suficientes datos para realizar el test
    if len(actual_prices) < 3:
        results.append([
            general_cat,
            specific_cat,
            'No aplicable (menos de 3 datos)',
            len(actual_prices),
            np.nan,
            'No se puede realizar el test de normalidad debido a la falta de datos',
            'No se puede realizar el test de normalidad'
        ])
        continue
    
    # Realizar el test de normalidad de Shapiro-Wilk
    _, p_value_shapiro = stats.shapiro(actual_prices)
    is_normal = p_value_shapiro > 0.05
    
    # Definir el grupo de comparación
    comparison_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] != specific_cat)
    ]
    
    # Convertir a valores numéricos, ignorando errores y eliminando NaN
    comparison_prices = pd.to_numeric(comparison_subset['actual_price'], errors='coerce').dropna()
    
    if len(comparison_prices) < 3:
        p_value = np.nan
        result_message = 'No se puede realizar el test de significancia debido a la falta de datos en el grupo de comparación'
    else:
        # Realizar el test adecuado
        if is_normal:
            # Test t para muestras independientes si la distribución es normal
            _, p_value = stats.ttest_ind(actual_prices, comparison_prices, equal_var=False)
        else:
            # Test Mann-Whitney U si la distribución no es normal
            _, p_value = stats.mannwhitneyu(actual_prices, comparison_prices)
        result_message = "El valor p es calculado y registrado."
    
    # Tamaño de la muestra
    sample_size = len(actual_prices)
    
    # Hipótesis redactada
    hypothesis = (
        f"No hay una diferencia significativa en el precio actual de los productos entre la categoría "
        f"específica '{specific_cat}' y otras categorías bajo '{general_cat}'" if p_value > 0.05 else
        f"Hay una diferencia significativa en el precio actual de los productos entre la categoría "
        f"específica '{specific_cat}' y otras categorías bajo '{general_cat}'"
    )
    
    # Resultado de la hipótesis
    result = "No se rechaza la hipótesis nula" if p_value > 0.05 else "Se rechaza la hipótesis nula"
    
    # Añadir los resultados a la lista
    results.append([
        general_cat,
        specific_cat,
        'Normal' if is_normal else 'No normal',
        sample_size,
        p_value,
        hypothesis,
        result
    ])

# Crear un DataFrame con los resultados
results_df = pd.DataFrame(results, columns=[
    'Categoría General', 'Categoría Específica', 'Tipo de Distribución',
    'Tamaño de la Muestra', 'p_value', 'Hipótesis', 'Resultado'
])

# Mostrar los resultados usando display
display(results_df)
# Out:
#        Categoría General Categoría Específica Tipo de Distribución  \
# 0            Electronics       RemoteControls            No normal
# 1  Computers&Accessories            USBCables            No normal
#
#    Tamaño de la Muestra       p_value  \
# 0                    48  5.711081e-10
# 1                   110  2.744520e-08
#
#                                            Hipótesis  \
# 0  Hay una diferencia significativa en el precio ...
# 1  Hay una diferencia significativa en el precio ...
#
#                       Resultado
# 0  Se rechaza la hipótesis nula
# 1  Se rechaza la hipótesis nula

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display
import textwrap

# Función para aplicar el wrap text
def wrap_text(text, width=50):
    return "\n".join(textwrap.wrap(text, width=width))

# Cargar el DataFrame df_unificado
df_unificado = amazon_unificado

# Definir las combinaciones específicas
specific_combinations = [
    ('Electronics', 'RemoteControls'),
    ('Computers&Accessories', 'USBCables'),
]

# Resultado esperado como DataFrame
results = []

# Iterar sobre las combinaciones específicas
for general_cat, specific_cat in specific_combinations:
    # Filtrar datos por categoría general y específica
    specific_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] == specific_cat)
    ]
    
    # Convertir a valores numéricos, ignorando errores y eliminando NaN
    actual_prices = pd.to_numeric(specific_subset['actual_price'], errors='coerce').dropna()
    
    # Verificar si hay suficientes datos para realizar el test
    if len(actual_prices) < 3:
        results.append([
            general_cat,
            specific_cat,
            'No aplicable (menos de 3 datos)',
            len(actual_prices),
            np.nan,
            'No se puede realizar el test de normalidad debido a la falta de datos',
            'No se puede realizar el test de normalidad'
        ])
        continue
    
    # Realizar el test de normalidad de Shapiro-Wilk
    _, p_value_shapiro = stats.shapiro(actual_prices)
    is_normal = p_value_shapiro > 0.05
    
    # Definir el grupo de comparación
    comparison_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] != specific_cat)
    ]
    
    # Convertir a valores numéricos, ignorando errores y eliminando NaN
    comparison_prices = pd.to_numeric(comparison_subset['actual_price'], errors='coerce').dropna()
    
    if len(comparison_prices) < 3:
        p_value = np.nan
        result_message = 'No se puede realizar el test de significancia debido a la falta de datos en el grupo de comparación'
    else:
        # Realizar el test adecuado
        if is_normal:
            # Test t para muestras independientes si la distribución es normal
            _, p_value = stats.ttest_ind(actual_prices, comparison_prices, equal_var=False)
        else:
            # Test Mann-Whitney U si la distribución no es normal
            _, p_value = stats.mannwhitneyu(actual_prices, comparison_prices)
        result_message = "El valor p es calculado y registrado."
    
    # Tamaño de la muestra
    sample_size = len(actual_prices)
    
    # Hipótesis redactada
    hypothesis = (
        "No hay una diferencia significativa en los precios (actual_price) entre las diferentes categorías "
        "(general_category y specific_category)." if p_value > 0.05 else
        "Hay una diferencia significativa en los precios (actual_price) entre las diferentes categorías "
        "(general_category y specific_category)."
    )
    
    # Resultado de la hipótesis
    result = "No se rechaza la hipótesis nula" if p_value > 0.05 else "Se rechaza la hipótesis nula"
    
    # Añadir los resultados a la lista
    results.append([
        wrap_text(general_cat),
        wrap_text(specific_cat),
        wrap_text('Normal' if is_normal else 'No normal'),
        sample_size,
        p_value,
        wrap_text(hypothesis),
        wrap_text(result)
    ])

# Crear un DataFrame con los resultados
results_df = pd.DataFrame(results, columns=[
    'Categoría General', 'Categoría Específica', 'Tipo de Distribución',
    'Tamaño de la Muestra', 'p_value', 'Hipótesis', 'Resultado'
])

# Mostrar los resultados usando display
display(results_df)
# Out:
#        Categoría General Categoría Específica Tipo de Distribución  \
# 0            Electronics       RemoteControls            No normal
# 1  Computers&Accessories            USBCables            No normal
#
#    Tamaño de la Muestra       p_value  \
# 0                    48  5.711081e-10
# 1                   110  2.744520e-08
#
#                                            Hipótesis  \
# 0  Hay una diferencia significativa en los precio...
# 1  Hay una diferencia significativa en los precio...
#
#                       Resultado
# 0  Se rechaza la hipótesis nula
# 1  Se rechaza la hipótesis nula

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display

# Cargar el DataFrame df_unificado con datos apropiados
df_unificado = amazon_unificado # Asegúrate de cargar tus datos aquí

# Definir combinaciones específicas
specific_combinations = [
    ('Electronics', 'RemoteControls'),
    ('Computers & Accessories', 'USBCables'),
]

results = []

for general_cat, specific_cat in specific_combinations:
    # Filtrar datos por categoría general y específica
    specific_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] == specific_cat)
    ]['actual_price'].dropna().apply(pd.to_numeric, errors='coerce').dropna()

    if len(specific_subset) < 3:
        results.append([
            general_cat, specific_cat, 'No aplicable', 'No aplicable',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable', 'Datos insuficientes', 'No aplicable', 'No aplicable'
        ])
        continue
    
    # Test de Shapiro-Wilk
    _, p_value_shapiro = stats.shapiro(specific_subset)
    is_normal = p_value_shapiro > 0.05
    
    # Definir el grupo de comparación
    comparison_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) &
        (df_unificado['specific_category'] != specific_cat)
    ]['actual_price'].dropna().apply(pd.to_numeric, errors='coerce').dropna()

    if len(comparison_subset) < 3:
        results.append([
            general_cat, specific_cat, 'Aprobado' if is_normal else 'Fallado', 'Normal' if is_normal else 'No normal',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable', 'Datos insuficientes para comparación', 'No aplicable', 'No aplicable'
        ])
        continue
    
    # Realizar prueba estadística adecuada
    if is_normal:
        stat, p_value = stats.ttest_ind(specific_subset, comparison_subset, equal_var=False)
        prueba_realizada = 'Prueba t'
    else:
        stat, p_value = stats.mannwhitneyu(specific_subset, comparison_subset)
        prueba_realizada = 'Mann-Whitney U'
    
    results.append([
        general_cat, specific_cat, 'Aprobado' if is_normal else 'Fallado', 'Normal' if is_normal else 'No normal',
        len(specific_subset), 'No hay diferencia significativa en los precios entre las categorías específicas y otras',
        'Prueba t si normal, Mann-Whitney U si no normal', prueba_realizada, f'{p_value:.2e}', 'No se rechaza' if p_value > 0.05 else 'Se rechaza',
        'El p-valor indica la probabilidad de obtener el resultado por azar', 'La relación es por azar' if p_value > 0.05 else 'La relación no es por azar'
    ])

results_df = pd.DataFrame(results, columns=[
    'Categoría General', 'Categoría Específica', 'Resultado Shapiro Will', 'Tipo de Distribución',
    'Tamaño de Muestra', 'Hipótesis (H0)', 'Prueba Recomendada', 'Prueba Realizada', 'P-Valor',
    'Resultado', 'Por Qué', 'Resultado Hipótesis'
])

# Ajustar el ancho de las columnas para una mejor visualización
pd.set_option('display.max_colwidth', None)

# Mostrar el DataFrame
display(results_df)

# Guardar el DataFrame en un archivo HTML
results_df.to_html('resultados_analisis.html', index=False)
# Out:
#          Categoría General Categoría Específica Resultado Shapiro Will  \
# 0              Electronics       RemoteControls                Fallado
# 1  Computers & Accessories            USBCables           No aplicable
#
#   Tipo de Distribución  Tamaño de Muestra  \
# 0            No normal                 48
# 1         No aplicable                  0
#
#                                                                             Hipótesis (H0)  \
# 0  No hay diferencia significativa en los precios entre las categorías específicas y otras
# 1                                                                             No aplicable
#
#                                 Prueba Recomendada Prueba Realizada  \
# 0  Prueba t si normal, Mann-Whitney U si no normal   Mann-Whitney U
# 1                                     No aplicable     No aplicable
#
#                P-Valor     Resultado  \
# 0             5.71e-10    Se rechaza
# 1  Datos insuficientes  No aplicable
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display

df_unificado = amazon_unificado

# Obtener todas las combinaciones de categorías generales y específicas
all_combinations = [(cat1, cat2) for cat1 in df_unificado['general_category'].unique() for cat2 in df_unificado['specific_category'].unique()]

results = []
for general_cat, specific_cat in all_combinations:
    specific_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) & 
        (df_unificado['specific_category'] == specific_cat)
    ]['actual_price'].dropna().apply(pd.to_numeric, errors='coerce').dropna()
    
    if len(specific_subset) < 3:
        results.append([
            None, general_cat, specific_cat, 'No aplicable', 'No aplicable',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable',
            'Datos insuficientes', 'No aplicable', 'No aplicable'
        ])
        continue

    comparison_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) & 
        (df_unificado['specific_category'] != specific_cat)
    ]['actual_price'].dropna().apply(pd.to_numeric, errors='coerce').dropna()
    
    if len(comparison_subset) < 3:
        results.append([
            None, general_cat, specific_cat, 
            'Aprobado' if stats.shapiro(specific_subset)[1] > 0.05 else 'Fallado',
            'Normal' if stats.shapiro(specific_subset)[1] > 0.05 else 'No normal',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable',
            'Datos insuficientes para comparación', 'No aplicable', 'No aplicable'
        ])
        continue

    is_normal = stats.shapiro(specific_subset)[1] > 0.05
    if is_normal:
        stat, p_value = stats.ttest_ind(specific_subset, comparison_subset, equal_var=False)
        prueba_realizada = 'Prueba t'
    else:
        stat, p_value = stats.mannwhitneyu(specific_subset, comparison_subset)
        prueba_realizada = 'Mann-Whitney U'

    results.append([
        None, general_cat, specific_cat,
        'Aprobado' if is_normal else 'Fallado',
        'Normal' if is_normal else 'No normal',
        len(specific_subset),
        'No hay diferencia significativa en los precios entre las categorías específicas y otras',
        'Prueba t si normal, Mann-Whitney U si no normal',
        prueba_realizada,
        f'{p_value:.2e}',
        'No se rechaza' if p_value > 0.05 else 'Se rechaza',
        'El p-valor indica la probabilidad de obtener el resultado por azar',
        'La relación es por azar' if p_value > 0.05 else 'La relación no es por azar'
    ])

results_df = pd.DataFrame(results, columns=[
    '#', 'Categoría General', 'Categoría Específica', 'Resultado Shapiro Will', 'Tipo de Distribución', 'Tamaño de Muestra',
    'Hipótesis (H0)', 'Prueba Recomendada', 'Prueba Realizada', 'P-Valor', 'Resultado', 'Por Qué', 'Resultado Hipótesis'
])

# Añadir la columna de numeración
results_df['#'] = range(1, len(results_df) + 1)

# Crear listas únicas para los filtros
general_categories = ['Todos'] + sorted(results_df['Categoría General'].unique())
specific_categories = ['Todos'] + sorted(results_df['Categoría Específica'].unique())
results_list = ['Todos'] + sorted(results_df['Resultado'].unique())
distributions = ['Todos'] + sorted(results_df['Tipo de Distribución'].unique())

# Formatear el DataFrame como una tabla con estilo de tarjetas (cards)
html_table = results_df.to_html(index=False, escape=False, table_id='results-table')
html_table = html_table.replace('<table', '<table class="card-table"')
html_table = html_table.replace('<th>', '<th class="card-header">')
html_table = html_table.replace('<td>', '<td class="card-body">')

with open('resultados_analisis_completo.html', 'w', encoding='utf-8') as f:
    f.write(f'''
    <!DOCTYPE html>
    <html>
        <head>
            <title>Resultados del Análisis</title>
            <style>
                .card-table {{
                    border-collapse: separate;
                    border-spacing: 16px;
                    width: 100%;
                }}
                .card-header {{
                    background-color: #f1f1f1;
                    padding: 12px;
                    border-top-left-radius: 8px;
                    border-top-right-radius: 8px;
                }}
                .card-body {{
                    background-color: white;
                    padding: 12px;
                    border-bottom-left-radius: 8px;
                    border-bottom-right-radius: 8px;
                    box-shadow: 0 4px 8px 0 rgba(0,0,0,0.2);
                }}
                .card-table tr:hover .card-body {{
                    box-shadow: 0 8px 16px 0 rgba(0,0,0,0.2);
                }}
                .filters {{
                    margin-bottom: 20px;
                    display: flex;
                    flex-wrap: wrap;
                    gap: 10px;
                }}
                .filter-box {{
                    width: 24%;
                    padding: 10px;
                    border-radius: 8px;
                    border: 1px solid #ccc;
                    font-size: 16px;
                }}
                #row-count {{
                    margin-bottom: 20px;
                }}
            </style>
        </head>
        <body>
            <div class="filters">
                <select class="filter-box" id="filter-general-cat">
                    {"".join(f'<option value="{cat}">{cat}</option>' for cat in general_categories)}
                </select>
                <select class="filter-box" id="filter-specific-cat">
                    {"".join(f'<option value="{cat}">{cat}</option>' for cat in specific_categories)}
                </select>
                <select class="filter-box" id="filter-result">
                    {"".join(f'<option value="{result}">{result}</option>' for result in results_list)}
                </select>
                <select class="filter-box" id="filter-distribution">
                    {"".join(f'<option value="{dist}">{dist}</option>' for dist in distributions)}
                </select>
            </div>
            <p id="row-count">Total de filas: {len(results_df)}</p>
            {html_table}
            <script>
                document.querySelectorAll('.filter-box').forEach(select => {{
                    select.addEventListener('change', filterTable);
                }});
                
                function filterTable() {{
                    let generalCat = document.getElementById('filter-general-cat').value;
                    let specificCat = document.getElementById('filter-specific-cat').value;
                    let result = document.getElementById('filter-result').value;
                    let distribution = document.getElementById('filter-distribution').value;
                    let rows = document.querySelectorAll('#results-table tbody tr');
                    let count = 0;
                    
                    rows.forEach(row => {{
                        let cells = row.querySelectorAll('td');
                        let showRow = 
                            (generalCat === 'Todos' || cells[1].textContent.includes(generalCat)) &&
                            (specificCat === 'Todos' || cells[2].textContent.includes(specificCat)) &&
                            (result === 'Todos' || cells[10].textContent.replace(/<\/?[^>]+>/gi, '').includes(result)) && // Revisión para HTML
                            (distribution === 'Todos' || cells[4].textContent.includes(distribution));
                        
                        row.style.display = showRow ? '' : 'none';
                        if (showRow) count++;
                    }});
                    
                    document.getElementById('row-count').textContent = 'Total de filas: ' + count;
                }}
            </script>
        </body>
    </html>
    ''')
# Out:
# <>:176: SyntaxWarning: invalid escape sequence '\/'
# <>:176: SyntaxWarning: invalid escape sequence '\/'
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_2400\1451349679.py:176: SyntaxWarning: invalid escape sequence '\/'
#   ''')

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import display

df_unificado = amazon_unificado

# Obtener todas las combinaciones de categorías generales y específicas
all_combinations = [(cat1, cat2) for cat1 in df_unificado['general_category'].unique() for cat2 in df_unificado['specific_category'].unique()]

results = []
for general_cat, specific_cat in all_combinations:
    specific_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) & 
        (df_unificado['specific_category'] == specific_cat)
    ]['discount_percentage'].dropna().apply(pd.to_numeric, errors='coerce').dropna()
    
    if len(specific_subset) < 3:
        results.append([
            None, general_cat, specific_cat, 'No aplicable', 'No aplicable',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable',
            'Datos insuficientes', 'No aplicable', 'No aplicable'
        ])
        continue

    comparison_subset = df_unificado[
        (df_unificado['general_category'] == general_cat) & 
        (df_unificado['specific_category'] != specific_cat)
    ]['discount_percentage'].dropna().apply(pd.to_numeric, errors='coerce').dropna()
    
    if len(comparison_subset) < 3:
        results.append([
            None, general_cat, specific_cat, 
            'Aprobado' if stats.shapiro(specific_subset)[1] > 0.05 else 'Fallado',
            'Normal' if stats.shapiro(specific_subset)[1] > 0.05 else 'No normal',
            len(specific_subset), 'No aplicable', 'No aplicable', 'No aplicable',
            'Datos insuficientes para comparación', 'No aplicable', 'No aplicable'
        ])
        continue

    is_normal = stats.shapiro(specific_subset)[1] > 0.05
    if is_normal:
        stat, p_value = stats.ttest_ind(specific_subset, comparison_subset, equal_var=False)
        prueba_realizada = 'Prueba t'
    else:
        stat, p_value = stats.mannwhitneyu(specific_subset, comparison_subset)
        prueba_realizada = 'Mann-Whitney U'

    results.append([
        None, general_cat, specific_cat,
        'Aprobado' if is_normal else 'Fallado',
        'Normal' if is_normal else 'No normal',
        len(specific_subset),
        'No hay diferencia significativa en los precios entre las categorías específicas y otras',
        'Prueba t si normal, Mann-Whitney U si no normal',
        prueba_realizada,
        f'{p_value:.2e}',
        'No se rechaza' if p_value > 0.05 else 'Se rechaza',
        'El p-valor indica la probabilidad de obtener el resultado por azar',
        'La relación es por azar' if p_value > 0.05 else 'La relación no es por azar'
    ])

results_df = pd.DataFrame(results, columns=[
    '#', 'Categoría General', 'Categoría Específica', 'Resultado Shapiro Will', 'Tipo de Distribución', 'Tamaño de Muestra',
    'Hipótesis (H0)', 'Prueba Recomendada', 'Prueba Realizada', 'P-Valor', 'Resultado', 'Por Qué', 'Resultado Hipótesis'
])

# Añadir la columna de numeración
results_df['#'] = range(1, len(results_df) + 1)

# Crear listas únicas para los filtros
general_categories = ['Todos'] + sorted(results_df['Categoría General'].unique())
specific_categories = ['Todos'] + sorted(results_df['Categoría Específica'].unique())
results_list = ['Todos'] + sorted(results_df['Resultado'].unique())
distributions = ['Todos'] + sorted(results_df['Tipo de Distribución'].unique())

# Formatear el DataFrame como una tabla con estilo de tarjetas (cards)
html_table = results_df.to_html(index=False, escape=False, table_id='results-table')
html_table = html_table.replace('<table', '<table class="card-table"')
html_table = html_table.replace('<th>', '<th class="card-header">')
html_table = html_table.replace('<td>', '<td class="card-body">')

with open('discount_percentage_resultados_analisis_completo.html', 'w', encoding='utf-8') as f:
    f.write(f'''
    <!DOCTYPE html>
    <html>
        <head>
            <title>Resultados del Análisis</title>
            <style>
                .card-table {{
                    border-collapse: separate;
                    border-spacing: 16px;
                    width: 100%;
                }}
                .card-header {{
                    background-color: #f1f1f1;
                    padding: 12px;
                    border-top-left-radius: 8px;
                    border-top-right-radius: 8px;
                }}
                .card-body {{
                    background-color: white;
                    padding: 12px;
                    border-bottom-left-radius: 8px;
                    border-bottom-right-radius: 8px;
                    box-shadow: 0 4px 8px 0 rgba(0,0,0,0.2);
                }}
                .card-table tr:hover .card-body {{
                    box-shadow: 0 8px 16px 0 rgba(0,0,0,0.2);
                }}
                .filters {{
                    margin-bottom: 20px;
                    display: flex;
                    flex-wrap: wrap;
                    gap: 10px;
                }}
                .filter-box {{
                    width: 24%;
                    padding: 10px;
                    border-radius: 8px;
                    border: 1px solid #ccc;
                    font-size: 16px;
                }}
                #row-count {{
                    margin-bottom: 20px;
                }}
            </style>
        </head>
        <body>
            <div class="filters">
                <select class="filter-box" id="filter-general-cat">
                    {"".join(f'<option value="{cat}">{cat}</option>' for cat in general_categories)}
                </select>
                <select class="filter-box" id="filter-specific-cat">
                    {"".join(f'<option value="{cat}">{cat}</option>' for cat in specific_categories)}
                </select>
                <select class="filter-box" id="filter-result">
                    {"".join(f'<option value="{result}">{result}</option>' for result in results_list)}
                </select>
                <select class="filter-box" id="filter-distribution">
                    {"".join(f'<option value="{dist}">{dist}</option>' for dist in distributions)}
                </select>
            </div>
            <p id="row-count">Total de filas: {len(results_df)}</p>
            {html_table}
            <script>
                document.querySelectorAll('.filter-box').forEach(select => {{
                    select.addEventListener('change', filterTable);
                }});
                
                function filterTable() {{
                    let generalCat = document.getElementById('filter-general-cat').value;
                    let specificCat = document.getElementById('filter-specific-cat').value;
                    let result = document.getElementById('filter-result').value;
                    let distribution = document.getElementById('filter-distribution').value;
                    let rows = document.querySelectorAll('#results-table tbody tr');
                    let count = 0;
                    
                    rows.forEach(row => {{
                        let cells = row.querySelectorAll('td');
                        let showRow = 
                            (generalCat === 'Todos' || cells[1].textContent.includes(generalCat)) &&
                            (specificCat === 'Todos' || cells[2].textContent.includes(specificCat)) &&
                            (result === 'Todos' || cells[10].textContent.replace(/<\/?[^>]+>/gi, '').includes(result)) && // Revisión para HTML
                            (distribution === 'Todos' || cells[4].textContent.includes(distribution));
                        
                        row.style.display = showRow ? '' : 'none';
                        if (showRow) count++;
                    }});
                    
                    document.getElementById('row-count').textContent = 'Total de filas: ' + count;
                }}
            </script>
        </body>
    </html>
    ''')
# Out:
# <>:176: SyntaxWarning: invalid escape sequence '\/'
# <>:176: SyntaxWarning: invalid escape sequence '\/'
# C:\Users\Oberb\AppData\Local\Temp\ipykernel_2400\498854986.py:176: SyntaxWarning: invalid escape sequence '\/'
#   ''')

# %% [markdown]
# # Regresion Lineal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df_unificado = amazon_unificado

# Mapeo de valores de texto a numéricos para 'rating_segmentation'
rating_segmentation_map = {
    "Rating Alto (Confiable)": 8,
    "Rating Alto (Moderadamente confiable)": 7,
    "Rating Alto (Medio confiable)": 6,
    "Rating Alto (Poco confiable)": 5,
    "Rating Bajo (Confiable)": 4,
    "Rating Bajo (Moderadamente confiable)": 3,
    "Rating Bajo (Medio confiable)": 2,
    "Rating Bajo (Poco confiable)": 1
}

# Mapeo de valores de texto a numéricos para 'general_category'
general_category_map = {
    "Home&Kitchen": 9,
    "Electronics": 8,
    "Computers&Accessories": 7,
    "OfficeProducts": 6,
    "MusicalInstruments": 5,
    "HomeImprovement": 4,
    "Toys&Games": 3,
    "Health&PersonalCare": 2,
    "Car&Motorbike": 1
}

# Transformar las variables categóricas a numéricas según el mapeo
df_unificado['segmentation_rating_num'] = df_unificado['rating_segmentation'].map(rating_segmentation_map)
df_unificado['general_category_num'] = df_unificado['general_category'].map(general_category_map)

# Transformar 'discount_percentage' a numérica quitando el símbolo '%'
df_unificado['discount_percentage_num'] = df_unificado['discount_percentage'].str.replace('%', '').astype(float)

# Visualización y regresión lineal para cada combinación
combinations = [
    ('segmentation_rating_num','rating_count'),
    ('rating', 'general_category_num'),
    ('rating', 'img_count'),
    ('rating', 'discount_percentage_num'),
    ('general_category_num', 'discount_percentage_num')
]

plt.figure(figsize=(12, 30))  # Ajusta el tamaño de la figura para más espacio vertical

for i, (x_var, y_var) in enumerate(combinations, start=1):
    x = df_unificado[x_var].dropna().values.reshape(-1, 1)
    y = df_unificado[y_var].dropna().values
    
    # Regresión lineal
    model = LinearRegression()
    model.fit(x, y)
    y_pred = model.predict(x)
    
    # Gráfico
    ax = plt.subplot(len(combinations), 1, i)
    ax.scatter(x, y, color='#DA70D6', label='Datos Reales', s=50)  # Color lila
    ax.plot(x, y_pred, color='#1E90FF', label='Regresión Lineal')  # Color azul en HEX
    
    # Ajustar el título con espaciado
    ax.set_title(f'Regresión Lineal: {x_var} vs {y_var}', fontsize=12, pad=10)  # Padding del título
    
    ax.set_xlabel(x_var)
    ax.set_ylabel(y_var)
    ax.legend()
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    # Ajustar el texto de "Cantidad de datos" con espaciado
    num_datos = len(x)
    ax.text(0.5, -0.2, f'Cantidad de datos en gráfica: {num_datos}', 
            ha='center', va='center', transform=ax.transAxes, fontsize=10, color='black')

# Ajusta el espacio entre subgráficos y los márgenes
plt.subplots_adjust(hspace=1.2, top=0.95, bottom=0.05, left=0.1, right=0.9)  # Ajusta los márgenes

plt.tight_layout(pad=10)  # Ajusta el espaciado interno para asegurar los márgenes

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Copiar el DataFrame para evitar modificaciones en el original
df_unificado = amazon_unificado.copy()

# Asegurarse de que las columnas están en el formato adecuado
df_unificado['rating'] = pd.to_numeric(df_unificado['rating'], errors='coerce')
df_unificado['img_count'] = pd.to_numeric(df_unificado['img_count'], errors='coerce')

# Eliminar filas con valores faltantes en las columnas relevantes
df_unificado = df_unificado.dropna(subset=['rating', 'img_count'])

# Dividir el DataFrame en dos subconjuntos
df_high_rating = df_unificado[df_unificado['rating'] >= 4]
df_low_rating = df_unificado[df_unificado['rating'] < 4]

# Definir las variables independientes y dependientes para cada subconjunto
X_high = df_high_rating[['rating']].values.reshape(-1, 1)
y_high = df_high_rating['img_count'].values

X_low = df_low_rating[['rating']].values.reshape(-1, 1)
y_low = df_low_rating['img_count'].values

# Crear y ajustar los modelos de regresión lineal
model_high = LinearRegression()
model_high.fit(X_high, y_high)
y_pred_high = model_high.predict(X_high)

model_low = LinearRegression()
model_low.fit(X_low, y_low)
y_pred_low = model_low.predict(X_low)

# Obtener los rangos del eje x
x_min = min(df_unificado['rating'].min(), 0)
x_max = df_unificado['rating'].max()

# Extender las líneas de tendencia a través de todo el rango del eje x
x_range = np.linspace(x_min, x_max, 100).reshape(-1, 1)
y_pred_high_full_range = model_high.predict(x_range)
y_pred_low_full_range = model_low.predict(x_range)

# Visualizar las regresiones lineales
plt.figure(figsize=(12, 6))

# Datos y línea de tendencia para calificaciones >= 4
plt.scatter(X_high, y_high, color='#DA70D6', label='Calificaciones >= 4', s=50)  # Color lila para los datos
plt.plot(x_range, y_pred_high_full_range, color='#1E90FF', label='Tendencia Calificaciones >= 4', linewidth=2)  # Línea azul

# Datos y línea de tendencia para calificaciones < 4
plt.scatter(X_low, y_low, color='#FF6347', label='Calificaciones < 4', s=50)  # Color rojo para los datos
plt.plot(x_range, y_pred_low_full_range, color='#FF4500', label='Tendencia Calificaciones < 4', linewidth=2)  # Línea naranja

# Ajustar el título y etiquetas
plt.title('Relación entre Calificación y Cantidad de Imágenes', fontsize=14)
plt.xlabel('Calificación')
plt.ylabel('Cantidad de Imágenes')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df_unificado = amazon_unificado.copy()

# Mapeo de valores de texto a numéricos para 'rating_segmentation'
rating_segmentation_map = {
    "Rating Alto (Confiable)": 8,
    "Rating Alto (Moderadamente confiable)": 7,
    "Rating Alto (Medio confiable)": 6,
    "Rating Alto (Poco confiable)": 5,
    "Rating Bajo (Confiable)": 4,
    "Rating Bajo (Moderadamente confiable)": 3,
    "Rating Bajo (Medio confiable)": 2,
    "Rating Bajo (Poco confiable)": 1
}

# Mapeo de valores de texto a numéricos para 'general_category'
general_category_map = {
    "Home&Kitchen": 9,
    "Electronics": 8,
    "Computers&Accessories": 7,
    "OfficeProducts": 6,
    "MusicalInstruments": 5,
    "HomeImprovement": 4,
    "Toys&Games": 3,
    "Health&PersonalCare": 2,
    "Car&Motorbike": 1
}

# Transformar las variables categóricas a numéricas según el mapeo
df_unificado['segmentation_rating_num'] = df_unificado['rating_segmentation'].map(rating_segmentation_map)
df_unificado['general_category_num'] = df_unificado['general_category'].map(general_category_map)

# Transformar 'discount_percentage' a numérica quitando el símbolo '%'
df_unificado['discount_percentage_num'] = df_unificado['discount_percentage'].str.replace('%', '').astype(float)

# Crear gráficos
num_plots = 5  # Número de gráficos a crear
plot_height_px = 700
plot_width_ratio = 0.8  # Porcentaje del ancho total para el gráfico
legend_width_ratio = 1 - plot_width_ratio  # Porcentaje del ancho total para la leyenda

plt.figure(figsize=(15, (plot_height_px / 100) * num_plots))  # Ajustar altura total de la figura

# Combinaciones de variables a graficar
combinations = [
    ('segmentation_rating_num', 'rating_count'),
    ('rating', 'general_category_num'),
    ('rating', 'img_count'),
    ('rating', 'discount_percentage_num'),
    ('general_category_num', 'discount_percentage_num')
]

for i, (x_var, y_var) in enumerate(combinations, start=1):
    ax = plt.subplot(num_plots, 1, i)
    
    # Seleccionar datos y ajustar el modelo
    x = df_unificado[x_var].dropna().values.reshape(-1, 1)
    y = df_unificado[y_var].dropna().values
    model = LinearRegression()
    model.fit(x, y)
    y_pred = model.predict(x)
    
    # Graficar datos reales y línea de tendencia
    ax.scatter(x, y, color='#DA70D6', label='Datos Reales', s=50)  # Color lila
    ax.plot(x, y_pred, color='#1E90FF', label='Regresión Lineal')  # Color azul en HEX
    
    # Configurar título y etiquetas
    ax.set_title(f'Regresión Lineal: {x_var} vs {y_var}', fontsize=12, pad=10)
    ax.set_xlabel(x_var)
    ax.set_ylabel(y_var)
    ax.legend(loc='best')
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    # Agregar leyenda de asignación
    if x_var == 'segmentation_rating_num':
        legend_title = 'Asignación Rating Segmentation'
        legend_labels = [f'{k}: {v}' for k, v in rating_segmentation_map.items()]
        legend_text = '\n'.join(legend_labels)
        ax.text(1 + (legend_width_ratio - 0.05), 0.5, f'{legend_title}\n{legend_text}', 
                transform=ax.transAxes, fontsize=10, va='center', ha='left', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

    elif x_var == 'general_category_num':
        legend_title = 'Asignación General Category'
        legend_labels = [f'{k}: {v}' for k, v in general_category_map.items()]
        legend_text = '\n'.join(legend_labels)
        ax.text(1 + (legend_width_ratio - 0.05), 0.5, f'{legend_title}\n{legend_text}', 
                transform=ax.transAxes, fontsize=10, va='center', ha='left', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

# Ajustar el espacio entre subgráficos y los márgenes
plt.subplots_adjust(hspace=0.5, top=0.95, bottom=0.05, left=0.05, right=1 - legend_width_ratio)  # Ajustar márgenes

plt.tight_layout(pad=10)  # Ajustar espaciado interno para asegurar márgenes

plt.show()

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression

df_unificado = amazon_unificado.copy()

# Combinaciones de variables a graficar
combinations = [
    ('rating', 'img_count'),
]

# Crear gráficos con Plotly
fig = go.Figure()

for i, (x_var, y_var) in enumerate(combinations, start=1):
    x = df_unificado[x_var].dropna().values.reshape(-1, 1)
    y = df_unificado[y_var].dropna().values
    model = LinearRegression()
    model.fit(x, y)
    y_pred = model.predict(x)
    
    # Agregar gráficos de dispersión y línea de regresión
    fig.add_trace(go.Scatter(x=x.flatten(), y=y, mode='markers', name=f'Datos Reales {x_var} vs {y_var}', marker=dict(color='#DA70D6', size=10)))
    fig.add_trace(go.Scatter(x=x.flatten(), y=y_pred, mode='lines', name=f'Regresión Lineal {x_var} vs {y_var}', line=dict(color='#1E90FF')))

# Ajustar la figura
fig.update_layout(
    title='Regresiones Lineales y Asignaciones',
    xaxis_title='Variables',
    yaxis_title='Valores',
    showlegend=True,
    autosize=False,
    width=1000,  # Ajusta el ancho total de la figura
    height=plot_height_px,  # Ajusta la altura total de la figura
    margin=dict(l=50, r=150, t=50, b=50)  # Ajusta los márgenes para espacio de leyenda
)

fig.show()

# %% [markdown]
# # TODOS Unificado Final

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import HTML
from sqlalchemy import create_engine
from IPython.display import display
from tabulate import tabulate

# Crear una cadena de conexión para SQLAlchemy
engine = create_engine('postgresql+psycopg2://osiris:121041@localhost:5432/datalab-osiris')

# Consulta para obtener el encabezado 
query_review_clean = "SELECT * FROM unificado_final"
unificado_final = pd.read_sql_query(query_review_clean, engine)


# Obtener el encabezado y el tipo de dato de cada columna
header_df = pd.DataFrame({
    'Nombre de la Variable': unificado_final.columns,
    'Tipo de Dato': [str(unificado_final[col].dtype) for col in unificado_final.columns]
})

# Obtener el conteo de valores nulos por columna
null_count_df = unificado_final.isnull().sum().reset_index()
null_count_df.columns = ['Nombre de la Variable', 'Conteo de Nulos']

# Imprimir las tablas en Jupyter Notebook
print("Encabezado del Unificado Final:")
display(header_df)

print("Conteo de Nulos:")
display(null_count_df)

# Imprimir el número de datos en el DataFrame
print(f"\nNúmero de datos en el DataFrame: {len(unificado_final)}")
# Out:
# Encabezado del Unificado Final:
#     Nombre de la Variable Tipo de Dato
# 0              product_id       object
# 1           reviews_count        int64
# 2               img_count        int64
# 3            actual_price      float64
# 4             dummy_price        int64
# 5     discount_percentage      float64
# 6          dummy_discount        int64
# 7                   score       object
# 8       rating_prediccion       object
# 9        discounted_price      float64
# 10       general_category       object
# 11      specific_category       object
# 12                 rating      float64
# 13        category_rating       object
# 14           rating_count        int64
# 15  category_rating_count       object
# 16    rating_segmentation       object
# Conteo de Nulos:
#     Nombre de la Variable  Conteo de Nulos
# 0              product_id                0
# 1           reviews_count                0
# 2               img_count                0
# ...

# %% [markdown]
# ## final
#
# # Train inicio
#
# * discount_percentage
# * dummy_discount
# * actual_price
# * dummy_price
# * rating

# %%
train = unificado_final

train[['discount_percentage','dummy_discount']].head()

# Revisar el rango

edad_min = train['discount_percentage'].min()
edad_max = train['discount_percentage'].max()
print(f'Rango de descuento: {edad_min} - {edad_max}')

# Revisar la distribución 

dummy_counts = train['dummy_discount'].value_counts()
print('Distribución de dummies:')
print(dummy_counts)

# Mostrar algunas estadísticas descriptivas de la variable 

print('Estadísticas descriptivas de la variable descuento:')
print(train['discount_percentage'].describe())
# Out:
# Rango de descuento: 0.0 - 94.0
# Distribución de dummies:
# dummy_discount
# 0    680
# 1    490
# Name: count, dtype: int64
# Estadísticas descriptivas de la variable descuento:
# count    1170.000000
# mean       46.450427
# std        21.496446
# min         0.000000
# 25%        32.000000
# 50%        49.000000
# 75%        62.000000
# max        94.000000
# Name: discount_percentage, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# 1 es alto, 0 es bajo

# asignacion binaria

train['aux_rating'] = train['rating'].apply(lambda x: 1 if x >= 4 else 0)

# Asignar las variables predictora y objetivo
X = train[['discount_percentage']].values  # Variable predictora continua
y = train['aux_rating'].values  # Variable objetivo binaria

model = LogisticRegression()
model.fit(X, y)

w = model.coef_[0][0]
b = model.intercept_[0]

print(f'Coeficiente w: {w}')
print(f'Intercepto b: {b}')

# Generate x values and compute corresponding y probabilities
x = np.linspace(X.min(), X.max(), 100)
y_prob = 1 / (1 + np.exp(-(w * x + b)))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, y_prob, '-r', label='Curva Logística')
plt.ylim(0, 1.1)
plt.xlabel('Descuento')
plt.ylabel('Probabilidad')
plt.title('Curva de Regresión Logística')
plt.legend()
plt.scatter(train['discount_percentage'], train['dummy_discount'], color='#BB86FC', label='Datos Reales')  # lila para los datos reales
plt.grid(True, color='#F48FB1', linestyle='-', linewidth=1)  
plt.gca().patch.set_facecolor('#FFFFFF')  
plt.gcf().set_facecolor('#FCE4EC')  
plt.show()
# Out:
# Coeficiente w: -0.01393263507541102
# Intercepto b: 1.6356594020141952

# %%
from sklearn.linear_model import LogisticRegression

# 1 es alto, 0 es bajo

# asignacion binaria

train['aux_rating'] = train['rating'].apply(lambda x: 1 if x >= 4 else 0)

# Asignar las variables predictora y objetivo
X = train[['actual_price']].values  # Variable predictora continua
y = train['aux_rating'].values  # Variable objetivo binaria

model = LogisticRegression()
model.fit(X, y)

w = model.coef_[0][0]
b = model.intercept_[0]

print(f'Coeficiente w: {w}')
print(f'Intercepto b: {b}')

# Generate x values and compute corresponding y probabilities
x = np.linspace(X.min(), X.max(), 100)
y_prob = 1 / (1 + np.exp(-(w * x + b)))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, y_prob, '-r', label='Curva Logística')
plt.ylim(0, 1.1)
plt.xlabel('Precio Actual')
plt.ylabel('Probabilidad')
plt.title('Curva de Regresión Logística')
plt.legend()
plt.scatter(train['actual_price'], train['dummy_price'], color='#BB86FC', label='Datos Reales')  # lila para los datos reales
plt.grid(True, color='#F48FB1', linestyle='-', linewidth=1)  
plt.gca().patch.set_facecolor('#FFFFFF')  
plt.gcf().set_facecolor('#FCE4EC')  
plt.show()
# Out:
# Coeficiente w: 3.563496852887674e-05
# Intercepto b: 0.8289732106992491
