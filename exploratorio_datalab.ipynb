# %% [markdown]
# # Traida de datos originales

# %%
import pandas as pd

# Rutas a los archivos CSV
archivo_product = 'CSV/amazon_product.csv'
archivo_review = 'CSV/amazon_review.csv'

# Leer los archivos CSV en DataFrames
df_productos = pd.read_csv(archivo_product) 
df_review = pd.read_csv(archivo_review)

# Mostrar los encabezados de cada DataFrame
print("Encabezados de df_productos:")
print(df_productos.columns.tolist())

print("\nEncabezados de df_review:")
print(df_review.columns.tolist())

# Contar el número de filas en cada DataFrame
print("\nNúmero de datos en df_productos:", df_productos.shape[0])
print("Número de datos en df_review:", df_review.shape[0])

# Contar los nulos en cada columna de df_productos
print("\nNúmero de nulos por columna en df_productos:")
print(df_productos.isnull().sum())

# Contar los nulos en cada columna de df_review
print("\nNúmero de nulos por columna en df_review:")
print(df_review.isnull().sum())

# Contar el número total de filas duplicadas en df_productos
print("\nNúmero total de filas duplicadas en df_productos:", df_productos.duplicated().sum())

# Contar duplicados por columna en df_productos
print("\nNúmero de duplicados por columna en df_productos:")
for col in df_productos.columns:
    print(f"{col}: {df_productos.duplicated(subset=[col]).sum()}")

# Contar el número total de filas duplicadas en df_review
print("\nNúmero total de filas duplicadas en df_review:", df_review.duplicated().sum())

# Contar duplicados por columna en df_review
print("\nNúmero de duplicados por columna en df_review:")
for col in df_review.columns:
    print(f"{col}: {df_review.duplicated(subset=[col]).sum()}")
# Out:
# Encabezados de df_productos:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'about_product']
#
# Encabezados de df_review:
# ['user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link', 'product_id', 'rating', 'rating_count']
#
# Número de datos en df_productos: 1469
# Número de datos en df_review: 1465
#
# Número de nulos por columna en df_productos:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          4
# dtype: int64
#
# Número de nulos por columna en df_review:
# user_id             0
# user_name           0
# review_id           0
# review_title        0
# review_content      0
# img_link          466
# product_link      466
# product_id          0
# rating              0
# rating_count        2
# dtype: int64
#
# ...

# %% [markdown]
# # Traida de datos limpios

# %%
import pandas as pd

# Rutas a los archivos CSV
archivo_product = 'CSV/amazon_product_clean.csv'
archivo_review = 'CSV/amazon_review_clean.csv'

# Leer los archivos CSV en DataFrames
df_productos = pd.read_csv(archivo_product) 
df_review = pd.read_csv(archivo_review)

# Mostrar los encabezados de cada DataFrame
print("Encabezados de df_productos:")
print(df_productos.columns.tolist())

print("\nEncabezados de df_review:")
print(df_review.columns.tolist())

# Contar el número de filas en cada DataFrame
print("\nNúmero de datos en df_productos:", df_productos.shape[0])
print("Número de datos en df_review:", df_review.shape[0])

# Contar los nulos en cada columna de df_productos
print("\nNúmero de nulos por columna en df_productos:")
print(df_productos.isnull().sum())

# Contar los nulos en cada columna de df_review
print("\nNúmero de nulos por columna en df_review:")
print(df_review.isnull().sum())

# Contar el número total de filas duplicadas en df_productos
print("\nNúmero total de filas duplicadas en df_productos:", df_productos.duplicated().sum())

# Contar duplicados por columna en df_productos
print("\nNúmero de duplicados por columna en df_productos:")
for col in df_productos.columns:
    print(f"{col}: {df_productos.duplicated(subset=[col]).sum()}")

# Contar el número total de filas duplicadas en df_review
print("\nNúmero total de filas duplicadas en df_review:", df_review.duplicated().sum())

# Contar duplicados por columna en df_review
print("\nNúmero de duplicados por columna en df_review:")
for col in df_review.columns:
    print(f"{col}: {df_review.duplicated(subset=[col]).sum()}")
# Out:
# Encabezados de df_productos:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'about_product', 'appearance_rank']
#
# Encabezados de df_review:
# ['reviews_count', 'review_title', 'review_content', 'img_link', 'product_link', 'product_id', 'rating', 'rating_count']
#
# Número de datos en df_productos: 1351
# Número de datos en df_review: 1186
#
# Número de nulos por columna en df_productos:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          0
# appearance_rank        0
# dtype: int64
#
# Número de nulos por columna en df_review:
# reviews_count     0
# review_title      0
# review_content    0
# img_link          0
# product_link      0
# product_id        0
# rating            0
# rating_count      0
# dtype: int64
#
# Número total de filas duplicadas en df_productos: 0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_review = pd.read_csv('CSV/amazon_review_clean.csv')

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['reviews_count'], color='#ADD8E6')
plt.title('reviews_count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_review = pd.read_csv('CSV/amazon_review_clean.csv')

# Convertir 'rating' a float usando el punto como separador decimal
df_review['rating'] = pd.to_numeric(df_review['rating'].str.replace(',', '.', regex=False), errors='coerce')

# Ordenar el DataFrame por 'rating'
df_review = df_review.sort_values(by='rating')

# Configurar el estilo de los gráficos
sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['rating'], color='#ADD8E6')
plt.title('rating')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
display(df_review)
# Out:
#       reviews_count                                       review_title  \
# 0                 2  (after nearly one year use) Value for money TV...
# 1                 8  **UPDATE MARCH2021**Decent for a USB 2.0 Devic...
# 2                 8  [Updated] decent tws for under 1k,Sound clarit...
# 3                 8  12V2A RouterUPS,Decent Product,Product quality...
# 4                 8  3,Sturdy and Works Flawlessly,Excellent 👍,Real...
# ...             ...                                                ...
# 1181              8  👍 nice,Lint removed instantly and effortlessly...
# 1182              8  👍,Good product,nice product,Satisfied,Value of...
# 1183              5  👍,Good quality product and value for money. Re...
# 1184              8  👎Disappointed 👎Review after 1 year 3 months of...
# 1185              8  💥,Considering the price range, it’s a good one...
#
#                                          review_content  \
# 0     ,What's not to love about this all-new 55 inch...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_review = pd.read_csv('CSV/amazon_review_clean.csv')

# Convertir la columna 'rating_count' a tipo numérico (int)
df_review['rating_count'] = pd.to_numeric(df_review['rating_count'], errors='coerce')

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_review['rating_count'], color='#ADD8E6')
plt.title('rating_count')


plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_product = pd.read_csv('CSV/amazon_product_clean.csv')

# Eliminar el símbolo ₹ y convertir a número
df_product['discounted_price'] = df_product['discounted_price'].replace({'₹': ''}, regex=True)
df_product['discounted_price'] = pd.to_numeric(df_product['discounted_price'], errors='coerce')

# Convertir a entero, manejando NaNs
df_product['discounted_price'] = df_product['discounted_price'].fillna(0).astype(int)

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['discounted_price'], color='#ADD8E6')
plt.title('discounted_price')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_product = pd.read_csv('CSV/amazon_product_clean.csv')

# Eliminar el símbolo ₹ y convertir a número
df_product['actual_price'] = df_product['actual_price'].replace({'₹': ''}, regex=True)
df_product['actual_price'] = pd.to_numeric(df_product['actual_price'], errors='coerce')

# Convertir a entero, manejando NaNs
df_product['actual_price'] = df_product['actual_price'].fillna(0).astype(int)

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['actual_price'], color='#ADD8E6')
plt.title('actual_price')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Leer el archivo CSV en un DataFrame
df_product = pd.read_csv('CSV/amazon_product_clean.csv')

# Ordenar el DataFrame por 'discount_percentage' de mayor a menor
df_product_sorted = df_product.sort_values(by='discount_percentage', ascending=False)

# Mostrar el DataFrame ordenado
display(df_product_sorted)
# Out:
#       product_id                                       product_name  \
# 830   B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 1299  B0BF54LXW6  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 1300  B0BF563HB4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 1297  B0BF4YBLPX  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 1301  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# ...          ...                                                ...
# 409   B07S851WX5            Prestige Sandwich Maker PGMFD 01, Black
# 365   B07LFQLKFZ  Parker Moments Vector Timecheck Gold Trim Roll...
# 124   B00YQLG7GK     PHILIPS HL1655/00 Hand Blender, White Jar 250W
# 350   B07KCMR8D6  Classmate Octane Neon- Blue Gel Pens(Pack of 5...
# 9     B0073QGKAS        Bajaj ATX 4 750-Watt Pop-up Toaster (White)
#
#                                                category  discounted_price  \
# 830   Computers&Accessories|Accessories&Peripherals|...             294.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_product = pd.read_csv('CSV/amazon_product_clean.csv')

# Convertir 'discount_percentage' a números y multiplicar por 100
df_product['discount_percentage'] = pd.to_numeric(df_product['discount_percentage'], errors='coerce')
df_product['discount_percentage'] = df_product['discount_percentage'] * 100

sns.set(style="whitegrid", rc={"axes.facecolor": "#f0f0f0", "grid.color": "#704214"})  # Fondo gris claro y grid sepia

plt.figure(figsize=(12, 6))
sns.boxplot(x=df_product['discount_percentage'], color='#ADD8E6')
plt.title('Discount Percentage')

# Configurar los ticks del eje x para que muestren valores en porcentaje
max_value = df_product['discount_percentage'].max()
plt.xticks(ticks=range(0, int(max_value) + 10, 10), labels=[f'{i}%' for i in range(0, int(max_value) + 10, 10)], rotation=45)

plt.tight_layout()
plt.show()
